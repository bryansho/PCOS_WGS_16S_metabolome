# %%
# Install and load R pakcages that are necessary for the analysis - Packages are collections of R functions, data, 
# and compiled code in a well-defined format. Remove the hash sign to download and install the packages.

#source('http://bioconductor.org/biocLite.R')
#biocLite('phyloseq')
library("phyloseq")
packageVersion("phyloseq")

#biocLite("biomformat")
library("biomformat")
packageVersion("biomformat")

#install.packages("ggplot2")
library("ggplot2")
packageVersion("ggplot2")

#install.packages("vegan")
library("vegan")
packageVersion('vegan')

#install.packages("grid")
library("grid")
packageVersion('grid')

#install.packages("magrittr")
library(magrittr)
packageVersion('magrittr')

library(dplyr)
packageVersion('dplyr')

library(plyr)
packageVersion('plyr')

library(broom)
packageVersion('broom')

library('stringr')
packageVersion('stringr')
# Out:
# [1] ‘1.26.1’
# [1] ‘1.10.1’
# [1] ‘3.3.1’
# [1] ‘2.5.6’
# [1] ‘3.5.1’
# [1] ‘1.5’
# [1] ‘1.0.0’
# [1] ‘1.8.6’
# [1] ‘0.5.6’
# [1] ‘1.4.0’

# %%
#Make sure the data has the sample names on rows if not just transform the data with t()
abund_table<-read.csv("table_cluster.tsv",sep ='\t',row.names=1,check.names=FALSE)
meta_table<-read.csv("mapping_file_cohousing2018.tsv",sep='\t',row.names=1,check.names=FALSE)
#Transpose the data to have sample names on rows
abund_table<-t(abund_table)

meta_table<-data.frame(meta_table)
#Filter out samples not present in meta_table
abund_table<-abund_table[rownames(abund_table) %in% rownames(meta_table),]

#Now load the taxonomy
OTU_taxonomy<-read.csv("taxonomy_phyloseq.csv",row.names=1,check.names=FALSE)
abund_table
meta_table
# Out:
#        81173df2e0d11f133fc2754e3298c119 1bbef1070bedf0db507fb6c7b5c28fff
# 570.T0    0                             4763
# 570.T1   47                             2957
# 570.T2    0                             6931
# 570.T3    0                             6113
# 570.T4   60                              487
# 570.T5    0                             4469
# 571.T0    0                              963
# 571.T1  168                             1429
# 571.T2  309                             1460
# 571.T3  137                              404
# 571.T4   79                              649
# 571.T5 1957                             3934
# 572.T0  496                             6527
# 572.T1    0                             5960
# 572.T2    9                             1471
# 572.T3   92                             2412
# 572.T4    0                              129
# 572.T5   61                              509
# 573.T0    0                              255
# 573.T1    0                              186
# 573.T2    0                             1864
# 573.T3  294                             3779
# 573.T4    0                             2145
# 573.T5 1473                             2737
# 574.T0    0                             8026
# 574.T1    0                             1082
# 574.T2    0                             7188
# 574.T3    0                             4210
# 574.T4    0                              991
# 574.T5    0                             4954
# ⋮      ⋮                                ⋮
# 598.T2   0                              5038
# 598.T3   0                               579
# 598.T4   0                              4308
# 598.T5   0                              3305
# 599.T0   0                              8434
# 599.T1  86                              1780
# 599.T2   0                               923
# 599.T3   0                                20
# 599.T4   0                              4045
# 599.T5  20                              4506
# 600.T0   0                              7787
# 600.T1   0                              2214
# 600.T2   0                              8516
# 600.T3   0                               516
# 600.T4   0                              4428
# 601.T0  13                              1118
# 601.T1   0                              1514
# 601.T2  30                              8510
# 601.T3   0                               177
# 601.T4   0                              2462
# 602.T0   0                              4196
# 602.T1   0                              2514
# 602.T2   0                              9046
# 602.T3   0                              3720
# 602.T4   0                              1872
# 603.T0   8                              4597
# 603.T1   0                              2210
# 603.T2 144                              6594
# 603.T3   0                              3417
# 603.T4  15                              4119
#        cf32fb1a1851ffab51de8b752990d321 3440e49bbd5cc4432ab49dd963d49bcd
# 570.T0  357                              248
# 570.T1  308                              266
# 570.T2  365                              309
# 570.T3  588                              595
# 570.T4   43                              215
# 570.T5  661                              343
# 571.T0  192                                0
# 571.T1  291                              244
# 571.T2  149                              185
# 571.T3  439                              530
# 571.T4  484                              453
# 571.T5  567                              506
# 572.T0    0                              551
# 572.T1  574                              342
# 572.T2  187                              169
# 572.T3  198                              197
# 572.T4  104                              115
# 572.T5  448                              216
# 573.T0  390                              461
# 573.T1  507                              721
# 573.T2  298                              276
# 573.T3  271                              174
# 573.T4  164                              196
# 573.T5  854                              451
# 574.T0  535                              521
# 574.T1  169                              215
# 574.T2 1526                             1258
# 574.T3 1292                              492
# 574.T4  116                                0
# 574.T5  866                              426
# ⋮      ⋮                                ⋮
# 598.T2  290                              214
# 598.T3  426                              753
# 598.T4  526                              280
# 598.T5  333                              259
# 599.T0  323                              277
# 599.T1  329                              352
# 599.T2  347                              146
# 599.T3    0                              105
# 599.T4  305                              302
# 599.T5  488                              214
# 600.T0  294                              647
# 600.T1  297                              262
# 600.T2  619                              437
# 600.T3  650                              791
# 600.T4  317                              211
# 601.T0  492                             2568
# 601.T1  176                              146
# 601.T2  311                              481
# 601.T3    0                                0
# 601.T4  149                              199
# 602.T0   97                              140
# 602.T1  318                              214
# 602.T2 1177                              649
# 602.T3  254                              215
# 602.T4  235                                0
# 603.T0  352                              561
# 603.T1  135                              177
# 603.T2 1305                              703
# 603.T3  365                              292
# 603.T4  239                              570
#        246d75fddaaf609d9e2ee0292360b064 37835e4fbbd6bb6b2f6dbbbad70f9372
# 570.T0   836                             387
# 570.T1   470                              39
# 570.T2   431                             221
# 570.T3  1210                             691
# 570.T4     0                             263
# 570.T5     0                             563
# 571.T0   576                               0
# 571.T1  1123                             296
# 571.T2   470                               0
# 571.T3   252                             361
# 571.T4   679                             400
# 571.T5   497                             371
# 572.T0 12916                               0
# 572.T1   204                             561
# 572.T2   345                             338
# 572.T3   381                             204
# 572.T4   522                              25
# 572.T5  1311                             639
# 573.T0 12262                             286
# 573.T1   354                             335
# 573.T2   728                             325
# 573.T3   351                             384
# 573.T4   369                             343
# 573.T5   534                            1002
# 574.T0   665                             420
# 574.T1  4902                              95
# 574.T2  2001                            1620
# 574.T3    29                             387
# 574.T4   273                               0
# 574.T5     0                             495
# ⋮      ⋮                                ⋮
# 598.T2   258                             408
# 598.T3   395                             885
# 598.T4    63                             195
# 598.T5   159                             515
# 599.T0     0                             361
# 599.T1  1909                             328
# 599.T2 10092                             222
# 599.T3   133                             179
# 599.T4  7759                             282
# 599.T5  2483                             462
# 600.T0   496                             571
# 600.T1   530                             196
# 600.T2   307                             631
# 600.T3   637                            1010
# 600.T4   232                             749
# 601.T0   444                             393
# 601.T1   259                              62
# 601.T2  6489                             573
# 601.T3   549                             167
# 601.T4  3259                             497
# 602.T0   757                               0
# 602.T1   192                             262
# 602.T2   559                             910
# 602.T3     0                             523
# 602.T4   235                             200
# 603.T0   382                             231
# 603.T1   291                               0
# 603.T2  1040                            1031
# 603.T3   327                             282
# 603.T4   296                             429
#        439e4f84c2a2e0c0f39e67ceabe0632a 7a82038a2a87643382fdc201dacb1009
# 570.T0  352                              879
# 570.T1  440                              568
# 570.T2  544                              693
# 570.T3  908                              550
# 570.T4   87                              136
# 570.T5  344                              379
# 571.T0    0                              358
# 571.T1  386                              547
# 571.T2    0                              274
# 571.T3  647                              523
# 571.T4  409                              660
# 571.T5  400                              600
# 572.T0  420                             1490
# 572.T1  389                              703
# 572.T2  307                              377
# 572.T3  288                              126
# 572.T4  237                              265
# 572.T5  338                              457
# 573.T0  362                              571
# 573.T1  352                              982
# 573.T2  400                              686
# 573.T3  411                              538
# 573.T4  335                              232
# 573.T5  601                              314
# 574.T0  428                             1300
# 574.T1  180                             1341
# 574.T2 1616                             1492
# 574.T3 1046                              362
# 574.T4  116                              229
# 574.T5  370                              492
# ⋮      ⋮                                ⋮
# 598.T2  314                              512
# 598.T3  958                             1034
# 598.T4  456                              486
# 598.T5  520                              330
# 599.T0  302                              282
# 599.T1  141                             1536
# 599.T2  152                              347
# 599.T3    0                               41
# 599.T4  392                              387
# 599.T5  528                              668
# 600.T0  436                              638
# 600.T1  337                              629
# 600.T2  485                              584
# 600.T3  785                              708
# 600.T4 1273                              601
# 601.T0  548                              871
# 601.T1  113                              190
# 601.T2  645                             1416
# 601.T3  157                              132
# 601.T4  298                              665
# 602.T0  104                              998
# 602.T1  361                              437
# 602.T2  821                             1180
# 602.T3  682                             1485
# 602.T4  136                              311
# 603.T0  240                              305
# 603.T1  209                              235
# 603.T2  851                              634
# 603.T3  439                              462
# 603.T4  358                              254
#        97855d38c5ce75bc28db3201640ab0b2 88b905e812e0d73b7a740796f1969218 ⋯
# 570.T0 608                               328                             ⋯
# 570.T1 104                               307                             ⋯
# 570.T2 486                               290                             ⋯
# 570.T3 297                              1064                             ⋯
# 570.T4  22                                 0                             ⋯
# 570.T5 218                               471                             ⋯
# 571.T0   0                               187                             ⋯
# 571.T1 203                               199                             ⋯
# 571.T2 148                                 0                             ⋯
# 571.T3 177                               464                             ⋯
# 571.T4 236                               352                             ⋯
# 571.T5 150                               512                             ⋯
# 572.T0 108                               580                             ⋯
# 572.T1 167                               588                             ⋯
# 572.T2 150                               392                             ⋯
# 572.T3 227                               213                             ⋯
# 572.T4 107                                 0                             ⋯
# 572.T5 689                               317                             ⋯
# 573.T0 152                               327                             ⋯
# 573.T1  17                               654                             ⋯
# 573.T2 234                               263                             ⋯
# 573.T3 266                               237                             ⋯
# 573.T4 161                               231                             ⋯
# 573.T5 422                               570                             ⋯
# 574.T0 708                               619                             ⋯
# 574.T1 619                               252                             ⋯
# 574.T2 844                              1349                             ⋯
# 574.T3 441                               522                             ⋯
# 574.T4 170                                 0                             ⋯
# 574.T5 370                               624                             ⋯
# ⋮      ⋮                                ⋮                                ⋱
# 598.T2 269                               284                             ⋯
# 598.T3  99                               861                             ⋯
# 598.T4 164                               799                             ⋯
# 598.T5 269                               369                             ⋯
# 599.T0 166                               194                             ⋯
# 599.T1 241                               324                             ⋯
# 599.T2   0                               219                             ⋯
# 599.T3   0                                 0                             ⋯
# 599.T4  17                               625                             ⋯
# 599.T5 137                               499                             ⋯
# 600.T0 229                               692                             ⋯
# 600.T1 208                               245                             ⋯
# 600.T2 441                               553                             ⋯
# 600.T3 429                               671                             ⋯
# 600.T4 302                               349                             ⋯
# 601.T0 312                              1260                             ⋯
# 601.T1 210                               157                             ⋯
# 601.T2 826                               630                             ⋯
# 601.T3 154                               109                             ⋯
# 601.T4  48                               182                             ⋯
# 602.T0 231                                 0                             ⋯
# 602.T1 227                               401                             ⋯
# 602.T2 552                              1022                             ⋯
# 602.T3 320                               458                             ⋯
# 602.T4 194                               158                             ⋯
# 603.T0 404                               200                             ⋯
# 603.T1 177                               293                             ⋯
# 603.T2 363                              1123                             ⋯
# 603.T3 166                               343                             ⋯
# 603.T4 189                               566                             ⋯
#        78bd4f10a55dea9609f3a8df20c20cba 960be8366f0574b960d18efa5b51f1a0
# 570.T0  0                               36
# 570.T1  0                               15
# 570.T2  0                               67
# 570.T3  0                               18
# 570.T4  0                                0
# 570.T5 60                                0
# 571.T0  0                                0
# 571.T1  0                                0
# 571.T2  0                                0
# 571.T3  0                               11
# 571.T4  0                                0
# 571.T5  0                                0
# 572.T0  0                                0
# 572.T1  0                                0
# 572.T2  0                                0
# 572.T3 60                                0
# 572.T4 10                                0
# 572.T5 18                                0
# 573.T0  0                               14
# 573.T1  0                               43
# 573.T2  0                               14
# 573.T3 22                                0
# 573.T4 21                                0
# 573.T5 21                                0
# 574.T0  0                                0
# 574.T1  0                                0
# 574.T2  7                               22
# 574.T3 22                                0
# 574.T4 21                                0
# 574.T5 33                               16
# ⋮      ⋮                                ⋮
# 598.T2 24                               15
# 598.T3  0                               22
# 598.T4 93                               75
# 598.T5 84                                0
# 599.T0 18                                0
# 599.T1  0                                0
# 599.T2  0                                0
# 599.T3  0                                0
# 599.T4 20                                0
# 599.T5  0                               34
# 600.T0  0                               22
# 600.T1  0                                0
# 600.T2  0                               19
# 600.T3  0                                0
# 600.T4 49                                0
# 601.T0  0                               22
# 601.T1  0                                0
# 601.T2 62                               54
# 601.T3  0                                0
# 601.T4  0                                0
# 602.T0  0                                0
# 602.T1  0                               22
# 602.T2 33                               55
# 602.T3  0                                0
# 602.T4 44                                0
# 603.T0  0                               25
# 603.T1  0                               25
# 603.T2  0                               46
# 603.T3  0                                0
# 603.T4  0                               37
#        4e933712b85bcbfbf13b99881e591140 d1824d652b46dd547a8893772c2e460e
# 570.T0   0                               0
# 570.T1  43                               0
# 570.T2 121                              82
# 570.T3  77                               0
# 570.T4   0                               0
# 570.T5   0                               0
# 571.T0   0                              31
# 571.T1  83                               0
# 571.T2  28                               0
# 571.T3  67                               0
# 571.T4   0                               0
# 571.T5 100                              42
# 572.T0   0                              64
# 572.T1   0                               0
# 572.T2   0                               0
# 572.T3  43                               0
# 572.T4   0                              39
# 572.T5   0                               0
# 573.T0  59                              55
# 573.T1   0                               0
# 573.T2   0                               0
# 573.T3  68                               0
# 573.T4   0                              45
# 573.T5   0                               0
# 574.T0   0                               0
# 574.T1  32                               0
# 574.T2  11                              16
# 574.T3   0                               0
# 574.T4  88                               0
# 574.T5   0                               0
# ⋮      ⋮                                ⋮
# 598.T2  0                                0
# 598.T3  0                                0
# 598.T4  0                               23
# 598.T5  0                                0
# 599.T0  0                                0
# 599.T1  0                                0
# 599.T2  0                               53
# 599.T3  0                                0
# 599.T4 65                                0
# 599.T5  0                               35
# 600.T0 20                                0
# 600.T1  0                                0
# 600.T2  0                                0
# 600.T3  0                                0
# 600.T4  0                               51
# 601.T0  0                                0
# 601.T1 64                                0
# 601.T2 74                               71
# 601.T3  0                                0
# 601.T4  0                               19
# 602.T0 53                                0
# 602.T1  0                                0
# 602.T2 58                                0
# 602.T3  0                                0
# 602.T4  0                                0
# 603.T0  0                                0
# 603.T1  0                                0
# 603.T2 74                               56
# 603.T3 73                               66
# 603.T4 62                                0
#        048dc38c4a9a224153a8666a4cbb07d1 ea50100bdb928864bf57323a91b085e7
# 570.T0  0                                0
# 570.T1  0                                0
# 570.T2 47                               46
# 570.T3 17                               37
# 570.T4  0                                0
# 570.T5  0                               10
# 571.T0  0                                0
# 571.T1  0                                0
# 571.T2  0                                7
# 571.T3 12                                0
# 571.T4  0                                0
# 571.T5  0                                0
# 572.T0  0                                0
# 572.T1  0                                9
# 572.T2  9                                0
# 572.T3  0                                0
# 572.T4 27                                0
# 572.T5  0                                0
# 573.T0  0                                0
# 573.T1 46                                0
# 573.T2  7                                0
# 573.T3 16                               17
# 573.T4 27                               18
# 573.T5  9                               16
# 574.T0  0                               13
# 574.T1  0                                0
# 574.T2 30                               32
# 574.T3  7                               30
# 574.T4 19                                0
# 574.T5  0                                0
# ⋮      ⋮                                ⋮
# 598.T2   0                               0
# 598.T3   0                              16
# 598.T4 122                               0
# 598.T5  11                              23
# 599.T0   0                               0
# 599.T1   0                              12
# 599.T2   0                               0
# 599.T3   0                               0
# 599.T4   0                              25
# 599.T5   8                              32
# 600.T0   0                               0
# 600.T1   0                               0
# 600.T2  38                              21
# 600.T3  15                              82
# 600.T4   0                              10
# 601.T0   0                              11
# 601.T1  13                               0
# 601.T2   0                               0
# 601.T3   0                               0
# 601.T4   0                               0
# 602.T0   0                               0
# 602.T1  27                               0
# 602.T2  32                              33
# 602.T3   0                              81
# 602.T4   0                               0
# 603.T0   0                              36
# 603.T1  22                              11
# 603.T2  17                              27
# 603.T3   0                               0
# 603.T4   7                              19
#        f04a9cacfbff7f4e852eaefc7d7517fa 833bc9dbc2bcefcdd26cf58205e1d427
# 570.T0  0                                0
# 570.T1 42                                0
# 570.T2 59                               48
# 570.T3  0                                0
# 570.T4  0                                0
# 570.T5  0                                0
# 571.T0  0                                0
# 571.T1 57                                0
# 571.T2  0                                4
# 571.T3 37                               12
# 571.T4 28                               26
# 571.T5 39                               17
# 572.T0  0                               21
# 572.T1 53                                0
# 572.T2  0                                0
# 572.T3  0                                0
# 572.T4  0                                0
# 572.T5  0                               19
# 573.T0  0                                0
# 573.T1 31                                0
# 573.T2  0                                0
# 573.T3  0                                0
# 573.T4 26                               17
# 573.T5  0                                0
# 574.T0  0                                0
# 574.T1  0                                0
# 574.T2 12                               10
# 574.T3  0                                0
# 574.T4  0                                0
# 574.T5 41                                0
# ⋮      ⋮                                ⋮
# 598.T2  0                                0
# 598.T3  0                                0
# 598.T4  0                                0
# 598.T5 55                                0
# 599.T0  0                                0
# 599.T1  0                                0
# 599.T2  0                                0
# 599.T3  0                                0
# 599.T4  0                               17
# 599.T5 28                                0
# 600.T0 23                                6
# 600.T1  0                                0
# 600.T2  0                               11
# 600.T3  0                                0
# 600.T4 53                                0
# 601.T0  0                                0
# 601.T1  0                                0
# 601.T2  0                               73
# 601.T3  0                                0
# 601.T4  0                                0
# 602.T0  0                                9
# 602.T1 32                                0
# 602.T2 35                                0
# 602.T3  0                                8
# 602.T4  0                                0
# 603.T0  0                                0
# 603.T1  0                                0
# 603.T2  0                               23
# 603.T3  0                               16
# 603.T4 33                                0
#        c2324ae27caa7b6227cd290adb9b7dd7 73c0a862e965920b132e83a4ef28af02
# 570.T0  0                                0
# 570.T1  0                               30
# 570.T2 32                               67
# 570.T3  0                               14
# 570.T4  0                                0
# 570.T5  0                                0
# 571.T0  0                                0
# 571.T1 14                               31
# 571.T2  0                                0
# 571.T3 11                                0
# 571.T4  0                               29
# 571.T5  0                                0
# 572.T0 15                               29
# 572.T1  0                                0
# 572.T2  0                                0
# 572.T3  0                               25
# 572.T4  0                               24
# 572.T5  0                                0
# 573.T0  0                                0
# 573.T1 13                                0
# 573.T2  6                               10
# 573.T3  0                               49
# 573.T4  0                               29
# 573.T5  0                                0
# 574.T0 35                                0
# 574.T1 18                               31
# 574.T2 10                               10
# 574.T3 13                                0
# 574.T4  0                                0
# 574.T5 15                                0
# ⋮      ⋮                                ⋮
# 598.T2  0                                0
# 598.T3  0                                0
# 598.T4  8                               32
# 598.T5  0                               21
# 599.T0 28                                0
# 599.T1 16                                0
# 599.T2  0                                0
# 599.T3  0                                0
# 599.T4 12                               41
# 599.T5  0                                0
# 600.T0  0                                0
# 600.T1  0                                0
# 600.T2  0                                0
# 600.T3 33                                0
# 600.T4 12                                0
# 601.T0  0                                0
# 601.T1  0                                0
# 601.T2 21                               50
# 601.T3  0                                0
# 601.T4  0                                0
# 602.T0 25                                0
# 602.T1  0                                0
# 602.T2 13                                0
# 602.T3 15                                0
# 602.T4  0                                0
# 603.T0 39                                0
# 603.T1  8                                0
# 603.T2  0                                0
# 603.T3  0                                0
# 603.T4  0                                0
#              Barcode      adaptor                TSRI_Seq_plate Well_Position
# 570.cacum.T5 TACAATATCTGT CCGGACTACHVGGGTWTCTAAT plate3         A07
# 570.T0       CACGTTTATTCC CCGGACTACHVGGGTWTCTAAT Plate1         A01
# 570.T1       GTTGATACGATG CCGGACTACHVGGGTWTCTAAT Plate1         C09
# 570.T2       AGTGTTTCGGAC CCGGACTACHVGGGTWTCTAAT Plate1         F05
# 570.T3       TCCCTTGTCTCC CCGGACTACHVGGGTWTCTAAT Plate2         A01
# 570.T4       GCATATGCACTG CCGGACTACHVGGGTWTCTAAT Plate2         C09
# 570.T5       TCTCTACCACTC CCGGACTACHVGGGTWTCTAAT Plate2         F05
# 571.cacum.T5 AATTTAGGTAGG CCGGACTACHVGGGTWTCTAAT plate3         A08
# 571.T0       GCAACGAACGAG CCGGACTACHVGGGTWTCTAAT Plate1         A02
# 571.T1       GTCAACGCTGTC CCGGACTACHVGGGTWTCTAAT Plate1         C10
# 571.T2       ACACGCGGTTTA CCGGACTACHVGGGTWTCTAAT Plate1         F06
# 571.T3       ACGAGACTGATT CCGGACTACHVGGGTWTCTAAT Plate2         A02
# 571.T4       CAACTCCCGTGA CCGGACTACHVGGGTWTCTAAT Plate2         C10
# 571.T5       AGAGCCAAGAGC CCGGACTACHVGGGTWTCTAAT Plate2         F06
# 572.cacum.T5 GACTCAACCAGT CCGGACTACHVGGGTWTCTAAT plate3         A09
# 572.T0       TGACTAATGGCC CCGGACTACHVGGGTWTCTAAT Plate1         A03
# 572.T1       TGAGACCCTACA CCGGACTACHVGGGTWTCTAAT Plate1         C11
# 572.T2       TGGCAAATCTAG CCGGACTACHVGGGTWTCTAAT Plate1         F07
# 572.T3       GCTGTACGGATT CCGGACTACHVGGGTWTCTAAT Plate2         A03
# 572.T4       TTGCGTTAGCAG CCGGACTACHVGGGTWTCTAAT Plate2         C11
# 572.T5       CTCACCTAGGAA CCGGACTACHVGGGTWTCTAAT Plate2         F07
# 573.cacum.T5 GCCTCTACGTCG CCGGACTACHVGGGTWTCTAAT plate3         A10
# 573.T0       CGGGACACCCGA CCGGACTACHVGGGTWTCTAAT Plate1         A04
# 573.T1       CCATGTGGCTCC CCGGACTACHVGGGTWTCTAAT Plate1         C12
# 573.T2       CACCTTACCTTA CCGGACTACHVGGGTWTCTAAT Plate1         F08
# 573.T3       ATCACCAGGTGT CCGGACTACHVGGGTWTCTAAT Plate2         A04
# 573.T4       TACGAGCCCTAA CCGGACTACHVGGGTWTCTAAT Plate2         C12
# 573.T5       GTGTTGTCGTGC CCGGACTACHVGGGTWTCTAAT Plate2         F08
# 574.cacum.T5 ACTACTGAGGAT CCGGACTACHVGGGTWTCTAAT plate3         A11
# 574.T0       CTGTCTATACTA CCGGACTACHVGGGTWTCTAAT Plate1         A05
# ⋮            ⋮            ⋮                      ⋮              ⋮
# 599.T0       GTAGTAGACCAT CCGGACTACHVGGGTWTCTAAT Plate1         C04
# ...
# 603.T1       GTAAATTCAGGC CCGGACTACHVGGGTWTCTAAT Plate1         F04
# 603.T2       CGATCTTCGAGC CCGGACTACHVGGGTWTCTAAT Plate1         H12
# 603.T3       AGTTACGAGCTA CCGGACTACHVGGGTWTCTAAT Plate2         C08
# 603.T4       TATCCAAGCGCA CCGGACTACHVGGGTWTCTAAT Plate2         F04
# 603.T5       GATCCCACGTAC CCGGACTACHVGGGTWTCTAAT Plate2         H12
#              Sequenc_.Name Sequence
# 570.cacum.T5 806rcbc198    TAC AAT ATC TGT CCG GAC TAC HVG GGT WTC TAA T
# 570.T0       806rcbc214    CAC GTT TAT TCC CCG GAC TAC HVG GGT WTC TAA T
# 570.T1       806rcbc246    GTT GAT ACG ATG CCG GAC TAC HVG GGT WTC TAA T
# 570.T2       806rcbc160    AGT GTT TCG GAC CCG GAC TAC HVG GGT WTC TAA T
# 570.T3       806rcbc0      TCC CTT GTC TCC CCG GAC TAC HVG GGT WTC TAA T
# 570.T4       806rcbc32     GCA TAT GCA CTG CCG GAC TAC HVG GGT WTC TAA T
# 570.T5       806rcbc64     TCT CTA CCA CTC CCG GAC TAC HVG GGT WTC TAA T
# 571.cacum.T5 806rcbc199    AAT TTA GGT AGG CCG GAC TAC HVG GGT WTC TAA T
# 571.T0       806rcbc215    GCA ACG AAC GAG CCG GAC TAC HVG GGT WTC TAA T
# 571.T1       806rcbc247    GTC AAC GCT GTC CCG GAC TAC HVG GGT WTC TAA T
# 571.T2       806rcbc161    ACA CGC GGT TTA CCG GAC TAC HVG GGT WTC TAA T
# 571.T3       806rcbc1      ACG AGA CTG ATT CCG GAC TAC HVG GGT WTC TAA T
# 571.T4       806rcbc33     CAA CTC CCG TGA CCG GAC TAC HVG GGT WTC TAA T
# 571.T5       806rcbc263    AGA GCC AAG AGC CCG GAC TAC HVG GGT WTC TAA T
# 572.cacum.T5 806rcbc200    GAC TCA ACC AGT CCG GAC TAC HVG GGT WTC TAA T
# 572.T0       806rcbc216    TGA CTA ATG GCC CCG GAC TAC HVG GGT WTC TAA T
# 572.T1       806rcbc248    TGA GAC CCT ACA CCG GAC TAC HVG GGT WTC TAA T
# 572.T2       806rcbc162    TGG CAA ATC TAG CCG GAC TAC HVG GGT WTC TAA T
# 572.T3       806rcbc2      GCT GTA CGG ATT CCG GAC TAC HVG GGT WTC TAA T
# 572.T4       806rcbc34     TTG CGT TAG CAG CCG GAC TAC HVG GGT WTC TAA T
# 572.T5       806rcbc66     CTC ACC TAG GAA CCG GAC TAC HVG GGT WTC TAA T
# 573.cacum.T5 806rcbc201    GCC TCT ACG TCG CCG GAC TAC HVG GGT WTC TAA T
# 573.T0       806rcbc217    CGG GAC ACC CGA CCG GAC TAC HVG GGT WTC TAA T
# 573.T1       806rcbc249    CCA TGT GGC TCC CCG GAC TAC HVG GGT WTC TAA T
# 573.T2       806rcbc163    CAC CTT ACC TTA CCG GAC TAC HVG GGT WTC TAA T
# 573.T3       806rcbc3      ATC ACC AGG TGT CCG GAC TAC HVG GGT WTC TAA T
# 573.T4       806rcbc35     TAC GAG CCC TAA CCG GAC TAC HVG GGT WTC TAA T
# 573.T5       806rcbc67     GTG TTG TCG TGC CCG GAC TAC HVG GGT WTC TAA T
# 574.cacum.T5 806rcbc202    ACT ACT GAG GAT CCG GAC TAC HVG GGT WTC TAA T
# 574.T0       806rcbc218    CTG TCT ATA CTA CCG GAC TAC HVG GGT WTC TAA T
# ⋮            ⋮             ⋮
# 599.T0       806rcbc241    GTA GTA GAC CAT CCG GAC TAC HVG GGT WTC TAA T
# 599.T1       806rcbc155    TCA GTT CTC GTT CCG GAC TAC HVG GGT WTC TAA T
# 599.T2       806rcbc187    TAT GTG CCG GCT CCG GAC TAC HVG GGT WTC TAA T
# 599.T3       806rcbc27     GTA TCT GCG CGT CCG GAC TAC HVG GGT WTC TAA T
# 599.T4       806rcbc59     ACA ATA GAC ACC CCG GAC TAC HVG GGT WTC TAA T
# 599.T5       806rcbc283    AAT GGT TCA GCA CCG GAC TAC HVG GGT WTC TAA T
# 600.T0       806rcbc242    AGT AAA GAT CGT CCG GAC TAC HVG GGT WTC TAA T
# 600.T1       806rcbc156    TCG TGC GTG TTG CCG GAC TAC HVG GGT WTC TAA T
# 600.T2       806rcbc188    TGG TCG CAT CGT CCG GAC TAC HVG GGT WTC TAA T
# 600.T3       806rcbc28     CGA GGG AAA GTC CCG GAC TAC HVG GGT WTC TAA T
# 600.T4       806rcbc60     CGG TCA ATT GAC CCG GAC TAC HVG GGT WTC TAA T
# 600.T5       806rcbc92     AGC AGA ACA TCT CCG GAC TAC HVG GGT WTC TAA T
# 601.T0       806rcbc243    CTC GCC CTC GCC CCG GAC TAC HVG GGT WTC TAA T
# 601.T1       806rcbc157    GTT ATC GCA TGG CCG GAC TAC HVG GGT WTC TAA T
# 601.T2       806rcbc189    TGT AAG ACT TGG CCG GAC TAC HVG GGT WTC TAA T
# 601.T3       806rcbc29     CAA ATT CGG GAT CCG GAC TAC HVG GGT WTC TAA T
# 601.T4       806rcbc261    ACG ACG CAT TTG CCG GAC TAC HVG GGT WTC TAA T
# 601.T5       806rcbc93     TGG AGT AGG TGG CCG GAC TAC HVG GGT WTC TAA T
# 602.T0       806rcbc244    TCT CTT TCG ACA CCG GAC TAC HVG GGT WTC TAA T
# 602.T1       806rcbc158    GAT CAC GAG AGG CCG GAC TAC HVG GGT WTC TAA T
# 602.T2       806rcbc190    CGG ATC TAG TGT CCG GAC TAC HVG GGT WTC TAA T
# 602.T3       806rcbc30     AGA TTG ACC AAC CCG GAC TAC HVG GGT WTC TAA T
# 602.T4       806rcbc62     GCT CGA AGA TTC CCG GAC TAC HVG GGT WTC TAA T
# 602.T5       806rcbc94     TTG GCT CTA TTC CCG GAC TAC HVG GGT WTC TAA T
# 603.T0       806rcbc245    ACA TAC TGA GCA CCG GAC TAC HVG GGT WTC TAA T
# 603.T1       806rcbc159    GTA AAT TCA GGC CCG GAC TAC HVG GGT WTC TAA T
# 603.T2       806rcbc191    CGA TCT TCG AGC CCG GAC TAC HVG GGT WTC TAA T
# 603.T3       806rcbc31     AGT TAC GAG CTA CCG GAC TAC HVG GGT WTC TAA T
# 603.T4       806rcbc262    TAT CCA AGC GCA CCG GAC TAC HVG GGT WTC TAA T
# 603.T5       806rcbc95     GAT CCC ACG TAC CCG GAC TAC HVG GGT WTC TAA T
#              PCR_Date Mouse Cage Week     ⋯ Lh    Insulin Testosterone Weight_g
# 570.cacum.T5 3_19_18  570   A    cacum.T5 ⋯    NA NA        NA         19.1
# 570.T0       3_20_18  570   A    0        ⋯    NA NA        NA         15.3
# 570.T1       3_20_18  570   A    1        ⋯    NA NA        NA         17.6
# 570.T2       3_15_18  570   A    2        ⋯    NA NA        NA         17.6
# 570.T3       3_16_18  570   A    3        ⋯    NA NA        NA         18.1
# 570.T4       3_16_18  570   A    4        ⋯    NA NA        NA         18.8
# 570.T5       3_17_18  570   A    5        ⋯ 0.472 396.3   46.2         19.1
# 571.cacum.T5 3_19_18  571   A    cacum.T5 ⋯    NA NA        NA         19.9
# 571.T0       3_20_18  571   A    0        ⋯    NA NA        NA         15.8
# 571.T1       3_20_18  571   A    1        ⋯    NA NA        NA         17.9
# 571.T2       3_15_18  571   A    2        ⋯    NA NA        NA         18.2
# 571.T3       3_16_18  571   A    3        ⋯    NA NA        NA         18.4
# 571.T4       3_16_18  571   A    4        ⋯    NA NA        NA         18.9
# 571.T5                571   A    5        ⋯ 0.036 484.1   14.6         19.9
# 572.cacum.T5 3_19_18  572   B    cacum.T5 ⋯    NA NA        NA         20.4
# 572.T0       3_20_18  572   B    0        ⋯    NA NA        NA         15.8
# 572.T1       3_20_18  572   B    1        ⋯    NA NA        NA         18.7
# 572.T2       3_15_18  572   B    2        ⋯    NA NA        NA         18.6
# 572.T3       3_16_18  572   B    3        ⋯    NA NA        NA         18.9
# 572.T4       3_16_18  572   B    4        ⋯    NA NA        NA         20.5
# 572.T5       3_17_18  572   B    5        ⋯ 0.236 536.6   13.9         20.4
# 573.cacum.T5 3_19_18  573   B    cacum.T5 ⋯    NA NA        NA         20.4
# 573.T0       3_20_18  573   B    0        ⋯    NA NA        NA         16.8
# 573.T1       3_20_18  573   B    1        ⋯    NA NA        NA         18.4
# 573.T2       3_15_18  573   B    2        ⋯    NA NA        NA         18.3
# 573.T3       3_16_18  573   B    3        ⋯    NA NA        NA         19.7
# 573.T4       3_16_18  573   B    4        ⋯    NA NA        NA         20.6
# 573.T5       3_17_18  573   B    5        ⋯ 0.654 373.3   18.6         20.4
# 574.cacum.T5 3_19_18  574   C    cacum.T5 ⋯    NA NA        NA         21.8
# 574.T0       3_20_18  574   C    0        ⋯    NA NA        NA         16.9
# ⋮            ⋮        ⋮     ⋮    ⋮        ⋱ ⋮     ⋮       ⋮            ⋮
# 599.T0       3_20_18  599   O    0        ⋯    NA NA        NA         17.3
# 599.T1       3_15_18  599   O    1        ⋯    NA NA        NA         18.6
# 599.T2       3_15_18  599   O    2        ⋯    NA NA        NA         20.4
# 599.T3       3_16_18  599   O    3        ⋯    NA NA        NA         20.0
# 599.T4       3_17_18  599   O    4        ⋯    NA NA        NA         20.1
# 599.T5                599   O    5        ⋯ 0.557 345.2   11.8         19.5
# 600.T0       3_20_18  600   P    0        ⋯    NA NA        NA         17.1
# 600.T1       3_15_18  600   P    1        ⋯    NA NA        NA         17.7
# 600.T2       3_15_18  600   P    2        ⋯    NA NA        NA         18.1
# 600.T3       3_16_18  600   P    3        ⋯    NA NA        NA         20.5
# 600.T4       3_17_18  600   P    4        ⋯    NA NA        NA         19.8
# 600.T5       3_19_18  600   P    5        ⋯ 0.020 206.2   23.7         19.8
# 601.T0       3_20_18  601   P    0        ⋯    NA NA        NA         17.0
# 601.T1       3_15_18  601   P    1        ⋯    NA NA        NA         17.7
# 601.T2       3_16_18  601   P    2        ⋯    NA NA        NA         20.4
# 601.T3       3_16_18  601   P    3        ⋯    NA NA        NA         22.4
# 601.T4                601   P    4        ⋯    NA NA        NA         21.2
# 601.T5       3_19_18  601   P    5        ⋯ 0.724 522.7   23.4         20.8
# 602.T0       3_20_18  602   Q    0        ⋯    NA NA        NA         18.3
# 602.T1       3_15_18  602   Q    1        ⋯    NA NA        NA         18.9
# 602.T2       3_16_18  602   Q    2        ⋯    NA NA        NA         19.3
# 602.T3       3_16_18  602   Q    3        ⋯    NA NA        NA         21.6
# 602.T4       3_17_18  602   Q    4        ⋯    NA NA        NA         20.3
# 602.T5       3_19_18  602   Q    5        ⋯ 0.183 281.6   14.7         21.4
# 603.T0       3_20_18  603   Q    0        ⋯    NA NA        NA         17.7
# 603.T1       3_15_18  603   Q    1        ⋯    NA NA        NA         18.5
# 603.T2       3_16_18  603   Q    2        ⋯    NA NA        NA         21.0
# 603.T3       3_16_18  603   Q    3        ⋯    NA NA        NA         24.0
# 603.T4                603   Q    4        ⋯    NA NA        NA         22.6
# 603.T5       3_19_18  603   Q    5        ⋯ 0.447 342.4   12.5         22.7
#              observed_SVs1250 pielou_e1250 faith_pd1250 shannon1250 FBG
# 570.cacum.T5 323              0.9645737    11.848214    8.040098     NA
# 570.T0       174              0.9380560     8.544578    6.981898     NA
# 570.T1       237              0.9523225     9.996757    7.512628     NA
# 570.T2       228              0.9395127    12.162930    7.359099     NA
# 570.T3       255              0.9421132    11.900200    7.531586     NA
# 570.T4        NA                     NA           NA          NA     NA
# 570.T5       266              0.9463011    11.998905    7.622723     NA
# 571.cacum.T5 246              0.9615278     9.938313    7.636948     NA
# 571.T0       207              0.9497070     9.534011    7.306559     NA
# 571.T1       275              0.9629449    11.811263    7.803020     NA
# 571.T2       129              0.9533197     9.423279    6.683941     NA
# 571.T3       258              0.9645749    11.427526    7.727429     NA
# 571.T4       326              0.9614757    13.136912    8.027099     NA
# 571.T5       336              0.9555696    13.520177    8.019444    153
# 572.cacum.T5 306              0.9639597    11.888165    7.959789     NA
# 572.T0       209              0.9273829     9.229722    7.147673     NA
# 572.T1       291              0.9494340     9.051822    7.770999     NA
# 572.T2       189              0.9521019    10.683466    7.200025     NA
# 572.T3       139              0.9508842    11.034204    6.769288     NA
# 572.T4       180              0.9508826    11.670401    7.123873     NA
# 572.T5       369              0.9657421    12.235200    8.235344    159
# 573.cacum.T5 240              0.9479924    10.995011    7.495672     NA
# 573.T0       300              0.9263588     9.977762    7.622839     NA
# 573.T1       340              0.9631027    11.368315    8.099107     NA
# 573.T2       204              0.9566564    10.480282    7.339875     NA
# 573.T3       265              0.9470566    13.665770    7.623662     NA
# 573.T4       183              0.9568525    12.119471    7.191416     NA
# 573.T5       220              0.9474423    11.149896    7.372389    164
# 574.cacum.T5 224              0.9595442    10.262375    7.491502     NA
# 574.T0       274              0.9402921     9.579756    7.614516     NA
# ⋮            ⋮                ⋮            ⋮            ⋮           ⋮
# 599.T0       221              0.9176189     8.360293    7.146327     NA
# 599.T1       226              0.9460051     8.125289    7.397929     NA
# 599.T2       181              0.9155017    10.526988    6.866122     NA
# 599.T3        24              0.8700310     3.815010    3.989060     NA
# 599.T4       210              0.9392283    10.366438    7.245438     NA
# 599.T5       314              0.9509514    11.123851    7.887781    132
# 600.T0       289              0.9237513    10.063209    7.551598     NA
# 600.T1       135              0.9385394     9.997417    6.641871     NA
# 600.T2       352              0.9351926    13.021913    7.911198     NA
# 600.T3       352              0.9603137    11.781383    8.123708     NA
# 600.T4       275              0.9446304    10.989994    7.654612     NA
# 600.T5        NA                     NA           NA          NA    145
# 601.T0       301              0.9448905     9.907318    7.779869     NA
# 601.T1       167              0.9475660    12.282906    6.996547     NA
# 601.T2       427              0.9498443    15.110296    8.299827     NA
# 601.T3        63              0.9468479     7.123152    5.659575     NA
# 601.T4       224              0.9544221     9.627506    7.451512     NA
# 601.T5        NA                     NA           NA          NA    163
# 602.T0       212              0.9490276    10.959136    7.334009     NA
# 602.T1       182              0.9435511    10.543362    7.083988     NA
# 602.T2       440              0.9445117    13.688195    8.294097     NA
# 602.T3       267              0.9534621    11.107601    7.685568     NA
# 602.T4        98              0.9427476     9.152041    6.236002     NA
# 602.T5        NA                     NA           NA          NA    116
# 603.T0       248              0.9424862     9.497725    7.496720     NA
# 603.T1       121              0.9425391     9.162003    6.521299     NA
# 603.T2       442              0.9602238    13.125845    8.438353     NA
# 603.T3       263              0.9512944    12.354961    7.647379     NA
# 603.T4       258              0.9557742    12.062462    7.656925     NA
# 603.T5        NA                     NA           NA          NA    122
#              Description
# 570.cacum.T5 570.cacum.T5
# 570.T0       570.T0
# 570.T1       570.T1
# 570.T2       570.T2
# 570.T3       570.T3
# 570.T4       570.T4
# 570.T5       570.T5
# 571.cacum.T5 571.cacum.T5
# 571.T0       571.T0
# 571.T1       571.T1
# 571.T2       571.T2
# 571.T3       571.T3
# 571.T4       571.T4
# 571.T5       571.T5
# 572.cacum.T5 572.cacum.T5
# 572.T0       572.T0
# 572.T1       572.T1
# 572.T2       572.T2
# 572.T3       572.T3
# 572.T4       572.T4
# 572.T5       572.T5
# 573.cacum.T5 573.cacum.T5
# 573.T0       573.T0
# 573.T1       573.T1
# 573.T2       573.T2
# 573.T3       573.T3
# 573.T4       573.T4
# 573.T5       573.T5
# 574.cacum.T5 574.cacum.T5
# 574.T0       574.T0
# ⋮            ⋮
# 599.T0       599.T0
# 599.T1       599.T1
# 599.T2       599.T2
# 599.T3       599.T3
# 599.T4       599.T4
# 599.T5       599.T5
# 600.T0       600.T0
# 600.T1       600.T1
# 600.T2       600.T2
# 600.T3       600.T3
# 600.T4       600.T4
# 600.T5       600.T5
# 601.T0       601.T0
# 601.T1       601.T1
# 601.T2       601.T2
# 601.T3       601.T3
# 601.T4       601.T4
# 601.T5       601.T5
# 602.T0       602.T0
# 602.T1       602.T1
# 602.T2       602.T2
# 602.T3       602.T3
# 602.T4       602.T4
# 602.T5       602.T5
# 603.T0       603.T0
# 603.T1       603.T1
# 603.T2       603.T2
# 603.T3       603.T3
# 603.T4       603.T4
# 603.T5       603.T5

# %%
#Convert the data to phyloseq format
OTU = otu_table(as.matrix(abund_table), taxa_are_rows = FALSE)
TAX = tax_table(as.matrix(OTU_taxonomy))
SAM = sample_data(meta_table)
physeq<-merge_phyloseq(phyloseq(OTU, TAX),SAM)

# %%
physeq
# Out:
# phyloseq-class experiment-level object
# otu_table()   OTU Table:         [ 186 taxa and 186 samples ]
# sample_data() Sample Data:       [ 186 samples by 25 sample variables ]
# tax_table()   Taxonomy Table:    [ 186 taxa by 7 taxonomic ranks ]

# %%
#Remove cecum and time 0
physeq.pt.BA = subset_samples(physeq, Week != '0')
physeq.pt.time2 = subset_samples(physeq.pt.BA, Week != '1' & Week != '3' & Week != '4' & Week != '5' & Week != 'cacum.T5')
physeq.pt.time5 = subset_samples(physeq.pt.BA, Week != '1' & Week != '3' & Week != '4' & Week != '2'& Week != 'cacum.T5')
#unique(sample_data(physeq.pt.BA)$Category)
#unique(sample_data(physeq.pt.BA)$Week)
unique(sample_data(physeq.pt.time2)$Category)
unique(sample_data(physeq.pt.time2)$Week)
unique(sample_data(physeq.pt.time5)$Category)
unique(sample_data(physeq.pt.time5)$Week)
# Out:
# [1] Placebo   Letrozole Co-P      Co-L
# Levels: Co-L Co-P Letrozole Placebo
# [1] 2
# Levels: 2
# [1] Placebo   Letrozole Co-P      Co-L
# Levels: Co-L Co-P Letrozole Placebo
# [1] 5
# Levels: 5

# %% [markdown]
# ## TIME 2

# %%
set.seed(123)
meta.rarefy.time2 = rarefy_even_depth(physeq.pt.time2, rngseed=1, sample.size=0.9*min(sample_sums(physeq.pt.time2)), replace=F)
# Out:
# `set.seed(1)` was used to initialize repeatable random subsampling.
#
# Please record this for your records so others can reproduce.
#
# Try `set.seed(1); .Random.seed` for the full vector
#
# ...

# %%
library('vegan')
###############################################
#####  PERMANOVA  ############-----------------
###############################################

#make a data frame from the sample_data (unweighted unifrac)
df = as(sample_data(meta.rarefy.time2), "data.frame")
d = phyloseq::distance(meta.rarefy.time2, "bray")

#test for homogeneity of data
sampledf <- data.frame(sample_data(meta.rarefy.time2))
beta <- betadisper(d, sampledf$Category)
permutest(beta)

CategorybetaDNA <- betadisper(d, sampledf$Category)
permutest(CategorybetaDNA)

pdf('16s_SV_T2_ellipse_filtered.pdf', width=20, height=15)
plot(CategorybetaDNA, ellipse = TRUE, hull=F)  
dev.off()

#now run permanova
set.seed(2)
GPNMDS = ordinate(meta.rarefy.time2, "PCoA", d)
sample_variables(meta.rarefy.time2)
a=adonis(d ~ Category, as(sample_data(meta.rarefy.time2), "data.frame"), permutations=1000, method='bray', weighted=FALSE)
a$aov.tab
# Out:
# Permutation test for homogeneity of multivariate dispersions
# Permutation: free
# Number of permutations: 999
#
# Response: Distances
#           Df  Sum Sq   Mean Sq      F N.Perm Pr(>F)
# Groups     3 0.00275 0.0009178 0.0392    999  0.995
# Residuals 27 0.63182 0.0234006
# Permutation test for homogeneity of multivariate dispersions
# Permutation: free
# Number of permutations: 999
#
# Response: Distances
#           Df  Sum Sq   Mean Sq      F N.Perm Pr(>F)
# Groups     3 0.00275 0.0009178 0.0392    999  0.996
# Residuals 27 0.63182 0.0234006
# png
#   2
#  [1] "Barcode"          "adaptor"          "TSRI_Seq_plate"   "Well_Position"
#  [5] "Sequenc_.Name"    "Sequence"         "PCR_Date"         "Mouse"
#  [9] "Cage"             "Week"             "mouse.time"       "Cecum"
# [13] "weight"           "Category"         "type"             "Lh"
# [17] "Insulin"          "Testosterone"     "Weight_g"         "observed_SVs1250"
# [21] "pielou_e1250"     "faith_pd1250"     "shannon1250"      "FBG"
# [25] "Description"
#           Df SumsOfSqs MeanSqs   F.Model  R2        Pr(>F)
# Category   3 0.4908703 0.1636234 1.210893 0.1185884 0.1928072
# Residuals 27 3.6484081 0.1351262       NA 0.8814116        NA
# Total     30 4.1392784        NA       NA 1.0000000        NA

# %%
set.seed(123)
DistBC = distance(meta.rarefy.time2, method = "bray")
#ordination
ordBC = ordinate(meta.rarefy.time2, method = "NMDS", distance = DistBC)
# Out:
# Run 0 stress 0.1095938
# Run 1 stress 0.1182067
# Run 2 stress 0.1198493
# Run 3 stress 0.1095935
# ... New best solution
# ... Procrustes: rmse 0.0004093173  max resid 0.001331684
# ... Similar to previous best
# Run 4 stress 0.1164457
# Run 5 stress 0.1182074
# Run 6 stress 0.1096943
# ... Procrustes: rmse 0.003378165  max resid 0.01391627
# Run 7 stress 0.118183
# Run 8 stress 0.1096018
# ... Procrustes: rmse 0.002667661  max resid 0.01297384
# Run 9 stress 0.1181834
# Run 10 stress 0.1164456
# Run 11 stress 0.1095938
# ... Procrustes: rmse 0.0003711012  max resid 0.00120703
# ... Similar to previous best
# Run 12 stress 0.1201395
# Run 13 stress 0.1095935
# ... New best solution
# ... Procrustes: rmse 5.462612e-05  max resid 0.0001902972
# ... Similar to previous best
# Run 14 stress 0.122227
# Run 15 stress 0.1099572
# ... Procrustes: rmse 0.0270251  max resid 0.1377548
# Run 16 stress 0.1095937
# ... Procrustes: rmse 0.0002230878  max resid 0.0008025957
# ... Similar to previous best
# Run 17 stress 0.1099574
# ... Procrustes: rmse 0.02700545  max resid 0.1376414
# Run 18 stress 0.1164484
# Run 19 stress 0.1095952
# ... Procrustes: rmse 0.0005584818  max resid 0.001885741
# ... Similar to previous best
# Run 20 stress 0.1099572
# ... Procrustes: rmse 0.02710523  max resid 0.13808
# *** Solution reached

# %%
cap_ord <- ordinate(
    physeq = meta.rarefy.time2, 
    method = "CAP",
    distance = "bray",
    formula = ~ Category 
)
pdf('16s_SV_T2_CAP_Filtered.pdf', width=15, height=15)
cap_plot <- plot_ordination(physeq = meta.rarefy.time2,ordination = cap_ord, 
    color = "Category",shape = "Category",axes = c(1,2)) + geom_point(size = 10)+
    scale_color_manual(values = c("blue", "purple", "darkgreen", "red", 
    "#1919ff", "darkorchid3", "black")) + ggtitle("CAP: Metabolite T2") + theme_bw() +
    theme(text = element_text(size = 50),
    panel.grid.major=element_blank(),
    panel.grid.minor=element_blank(), 
    panel.background=element_rect(colour="black",fill=NA,size=2)) + 
    scale_shape_manual(values=c(15,18,17,19)) + geom_hline(yintercept=0,colour="black",linetype="dashed") + 
    geom_vline(xintercept=0,colour="black",linetype="dashed") 
cap_plot
dev.off()
# Out:
# png
#   2

# %%
print('BrayCurtis Permanova')
a=adonis(DistBC ~  Category, as(sample_data(meta.rarefy.time2), "data.frame"), permutations=1000, method='bray')
a$aov.tab
# Out:
# [1] "BrayCurtis Permanova"
#           Df SumsOfSqs MeanSqs   F.Model  R2        Pr(>F)
# Category   3 0.4908703 0.1636234 1.210893 0.1185884 0.1908092
# Residuals 27 3.6484081 0.1351262       NA 0.8814116        NA
# Total     30 4.1392784        NA       NA 1.0000000        NA

# %% [markdown]
# ## TIME 5

# %%
set.seed(123)
meta.rarefy.time5 = rarefy_even_depth(physeq.pt.time5, rngseed=1, sample.size=0.9*min(sample_sums(physeq.pt.time5)), replace=F)
# Out:
# `set.seed(1)` was used to initialize repeatable random subsampling.
#
# Please record this for your records so others can reproduce.
#
# Try `set.seed(1); .Random.seed` for the full vector
#
# ...

# %%
library('vegan')
###############################################
#####  PERMANOVA  ############-----------------
###############################################

#make a data frame from the sample_data (unweighted unifrac)
df = as(sample_data(meta.rarefy.time5), "data.frame")
d = phyloseq::distance(meta.rarefy.time5, "bray")

#test for homogeneity of data
sampledf <- data.frame(sample_data(meta.rarefy.time5))
beta <- betadisper(d, sampledf$Category)
permutest(beta)

CategorybetaDNA <- betadisper(d, sampledf$Category)
permutest(CategorybetaDNA)

pdf('16s_SV_T5_ellipse_filtered.pdf', width=20, height=15)
plot(CategorybetaDNA, ellipse = TRUE, hull=F)  
dev.off()

#now run permanova
set.seed(2)
GPNMDS = ordinate(meta.rarefy.time5, "PCoA", d)
sample_variables(meta.rarefy.time5)
a=adonis(d ~ Category, as(sample_data(meta.rarefy.time5), "data.frame"), permutations=1000, method='bray', weighted=FALSE)
a$aov.tab
# Out:
# Permutation test for homogeneity of multivariate dispersions
# Permutation: free
# Number of permutations: 999
#
# Response: Distances
#           Df   Sum Sq   Mean Sq     F N.Perm Pr(>F)
# Groups     3 0.020441 0.0068137 1.337    999  0.282
# Residuals 24 0.122314 0.0050964
# Permutation test for homogeneity of multivariate dispersions
# Permutation: free
# Number of permutations: 999
#
# Response: Distances
#           Df   Sum Sq   Mean Sq     F N.Perm Pr(>F)
# Groups     3 0.020441 0.0068137 1.337    999  0.315
# Residuals 24 0.122314 0.0050964
# png
#   2
#  [1] "Barcode"          "adaptor"          "TSRI_Seq_plate"   "Well_Position"
#  [5] "Sequenc_.Name"    "Sequence"         "PCR_Date"         "Mouse"
#  [9] "Cage"             "Week"             "mouse.time"       "Cecum"
# [13] "weight"           "Category"         "type"             "Lh"
# [17] "Insulin"          "Testosterone"     "Weight_g"         "observed_SVs1250"
# [21] "pielou_e1250"     "faith_pd1250"     "shannon1250"      "FBG"
# [25] "Description"
#           Df SumsOfSqs MeanSqs    F.Model  R2        Pr(>F)
# Category   3 0.3056459 0.10188197 1.086154 0.1195394 0.2787213
# Residuals 24 2.2512169 0.09380071       NA 0.8804606        NA
# Total     27 2.5568628         NA       NA 1.0000000        NA

# %%
set.seed(123)
DistBC = distance(meta.rarefy.time5, method = "bray")
#ordination
ordBC = ordinate(meta.rarefy.time5, method = "NMDS", distance = DistBC)
# Out:
# Run 0 stress 0.1508713
# Run 1 stress 0.1554506
# Run 2 stress 0.1599359
# Run 3 stress 0.1508705
# ... New best solution
# ... Procrustes: rmse 0.0007639517  max resid 0.002522052
# ... Similar to previous best
# Run 4 stress 0.1554167
# Run 5 stress 0.1508713
# ... Procrustes: rmse 0.0005118284  max resid 0.001649163
# ... Similar to previous best
# Run 6 stress 0.1554464
# Run 7 stress 0.1516553
# Run 8 stress 0.1983792
# Run 9 stress 0.2048478
# Run 10 stress 0.1554155
# Run 11 stress 0.1508718
# ... Procrustes: rmse 0.001005233  max resid 0.002771373
# ... Similar to previous best
# Run 12 stress 0.1508719
# ... Procrustes: rmse 0.0003786958  max resid 0.001013579
# ... Similar to previous best
# Run 13 stress 0.15087
# ... New best solution
# ... Procrustes: rmse 0.0005213999  max resid 0.001915128
# ... Similar to previous best
# Run 14 stress 0.1508702
# ... Procrustes: rmse 0.0004259877  max resid 0.001245186
# ... Similar to previous best
# Run 15 stress 0.1508718
# ... Procrustes: rmse 0.0008908294  max resid 0.003333953
# ... Similar to previous best
# Run 16 stress 0.1516563
# Run 17 stress 0.1516546
# Run 18 stress 0.1599209
# Run 19 stress 0.179884
# Run 20 stress 0.1732071
# *** Solution reached

# %%
cap_ord <- ordinate(
    physeq = meta.rarefy.time5, 
    method = "CAP",
    distance = "bray",
    formula = ~ Category 
)
pdf('16s_SV_T5_CAP_filtered.pdf', width=15, height=15)
cap_plot <- plot_ordination(physeq = meta.rarefy.time5,ordination = cap_ord, 
    color = "Category",shape = "Category",axes = c(1,2)) + geom_point(size = 10)+
    scale_color_manual(values = c("blue", "purple", "darkgreen", "red", 
    "#1919ff", "darkorchid3", "black")) + ggtitle("CAP: 16S T5") + theme_bw() +
    theme(text = element_text(size = 50),
    panel.grid.major=element_blank(),
    panel.grid.minor=element_blank(), 
    panel.background=element_rect(colour="black",fill=NA,size=2)) + 
    scale_shape_manual(values=c(15,18,17,19)) + geom_hline(yintercept=0,colour="black",linetype="dashed") + 
    geom_vline(xintercept=0,colour="black",linetype="dashed") 
cap_plot
dev.off()
# Out:
# png
#   2

# %%
print('BrayCurtis Permanova')
a=adonis(DistBC ~  Category, as(sample_data(meta.rarefy.time5), "data.frame"), permutations=1000, method='bray')
a$aov.tab
# Out:
# [1] "BrayCurtis Permanova"
#           Df SumsOfSqs MeanSqs    F.Model  R2        Pr(>F)
# Category   3 0.3056459 0.10188197 1.086154 0.1195394 0.3226773
# Residuals 24 2.2512169 0.09380071       NA 0.8804606        NA
# Total     27 2.5568628         NA       NA 1.0000000        NA
