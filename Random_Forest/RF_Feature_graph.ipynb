# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("RF_top_features.csv")
df
# Out:
#                     Comparison                                     Feature  \
# 0              T2_PvL_(BA+WSG)                     s_Lactobacillus_reuteri
# 1              T2_PvL_(BA+WSG)                   Lithocholic acid (NIST14)
# 2              T2_PvL_(BA+WSG)                   s_Akkermansia_muciniphila
# 3              T2_PvL_(BA+WSG)      3_-Hydroxy-5-cholenoic acid (NIST14).1
# 4              T2_PvL_(BA+WSG)                           Ursocholic acid.3
# 5              T2_PvL_(BA+WSG)      3_-Hydroxy-5-cholenoic acid (NIST14).4
# 6              T2_PvL_(BA+WSG)                               Cholic acid.7
# 7              T2_PvL_(BA+WSG)               s_Parabacteroides_goldsteinii
# 8              T2_PvL_(BA+WSG)                   s_Lactobacillus_johnsonii
# 9              T2_PvL_(BA+WSG)                       Chenodeoxycholic acid
# 10    T2_PvL_(Metabolomic+WSG)                                    Bacosine
# 11    T2_PvL_(Metabolomic+WSG)                 Oleanolic acid methyl ester
# 12    T2_PvL_(Metabolomic+WSG)      4-dihydroxyheptadec-16-en-2-yl acetate
# 13    T2_PvL_(Metabolomic+WSG)                   s_Akkermansia_muciniphila
# 14    T2_PvL_(Metabolomic+WSG)                     s_Lactobacillus_gasseri
# 15    T2_PvL_(Metabolomic+WSG)                     s_Lactobacillus_murinus
# 16    T2_PvL_(Metabolomic+WSG)                   s_Lactobacillus_johnsonii
# 17    T2_PvL_(Metabolomic+WSG)          cis-581114-Eicosatetraenoic acid.1
# 18    T2_PvL_(Metabolomic+WSG)                           Urobilin (NIST14)
# 19    T2_PvL_(Metabolomic+WSG)                                      Phenol
# 20           T2_LvCoL_(BA+WSG)      3_-Hydroxy-5-cholenoic acid (NIST14).1
# 21           T2_LvCoL_(BA+WSG)                     Cholic acid (NIST14).19
# 22           T2_LvCoL_(BA+WSG)                   Lithocholic acid (NIST14)
# 23           T2_LvCoL_(BA+WSG)                     Cholic acid (NIST14).17
# 24           T2_LvCoL_(BA+WSG)                    Cholic acid methyl ester
# 25           T2_LvCoL_(BA+WSG)                    s_Lactobacillus_animalis
# 26           T2_LvCoL_(BA+WSG)                     s_Lactobacillus_murinus
# 27           T2_LvCoL_(BA+WSG)        Tauroursodeoxycholic acid (NIST14).1
# 28           T2_LvCoL_(BA+WSG)                     Cholic acid (NIST14).14
# 29           T2_LvCoL_(BA+WSG)                          Taurocholic acid.1
# ..                         ...                                         ...
# 50    T5_PvL_(Metabolomic+WSG)                     s_Lactobacillus_gasseri
# 51    T5_PvL_(Metabolomic+WSG)                                    Bacosine
# 52    T5_PvL_(Metabolomic+WSG)                     s_Lactobacillus_reuteri
# 53    T5_PvL_(Metabolomic+WSG)                    s_Entomoplasma_freundtii
# 54    T5_PvL_(Metabolomic+WSG)               s_Parabacteroides_goldsteinii
# 55    T5_PvL_(Metabolomic+WSG)      s_Candidatus_Arthromitus_sp._SFB-mouse
# 56    T5_PvL_(Metabolomic+WSG)                   s_Lactobacillus_johnsonii
# 57    T5_PvL_(Metabolomic+WSG)                        s_Vibrio_sp._2521-89
# 58    T5_PvL_(Metabolomic+WSG)              s_Bifidobacterium_pseudolongum
# 59    T5_PvL_(Metabolomic+WSG)   s_Candidatus_Arthromitus_sp._SFB-mouse-NL
# 60           T5_LvCoL_(BA+WSG)                        _-Muricholic acid.13
# 61           T5_LvCoL_(BA+WSG)              s_Bifidobacterium_pseudolongum
# 62           T5_LvCoL_(BA+WSG)                         s_Borrelia_anserina
# 63           T5_LvCoL_(BA+WSG)                    s_Entomoplasma_freundtii
# 64           T5_LvCoL_(BA+WSG)                     _-Hyodeoxycholic acid.7
# 65           T5_LvCoL_(BA+WSG)                  s_Corynebacterium_uterequi
# 66           T5_LvCoL_(BA+WSG)                   s_Lactobacillus_johnsonii
# 67           T5_LvCoL_(BA+WSG)                s_Pseudobutyrivibrio_ruminis
# 68           T5_LvCoL_(BA+WSG)                     s_Lactobacillus_gasseri
# 69           T5_LvCoL_(BA+WSG)                    Cholic acid methyl ester
# 70  T5_LvCoL_(Metabolomic+WSG)                  s_Corynebacterium_uterequi
# 71  T5_LvCoL_(Metabolomic+WSG)     1-Palmitoyl-sn-glycero-3-phosphocholine
# 72  T5_LvCoL_(Metabolomic+WSG)          cis-581114-Eicosatetraenoic acid.1
# 73  T5_LvCoL_(Metabolomic+WSG)             1-Phenanthrenecarboxylic acid.1
# 74  T5_LvCoL_(Metabolomic+WSG)                                 Hederagenin
# 75  T5_LvCoL_(Metabolomic+WSG)                          Sumaresinolic acid
# 76  T5_LvCoL_(Metabolomic+WSG)                  Linoleic acid methyl ester
# 77  T5_LvCoL_(Metabolomic+WSG)                     s_Lactobacillus_gasseri
# 78  T5_LvCoL_(Metabolomic+WSG)                phosphoethanolamine (NIST14)
# 79  T5_LvCoL_(Metabolomic+WSG)                         3-Hydroxykynurenine
#
#     Importance
# 0      0.240000
# 1      0.100000
# 2      0.080000
# 3      0.060000
# 4      0.050000
# 5      0.040000
# 6      0.030000
# 7      0.030000
# 8      0.030000
# 9      0.030000
# 10     0.075715
# 11     0.058373
# 12     0.056586
# 13     0.042088
# 14     0.041901
# 15     0.039571
# 16     0.037748
# 17     0.032912
# 18     0.032727
# 19     0.030448
# 20     0.115000
# 21     0.107500
# 22     0.095000
# 23     0.065000
# 24     0.055000
# 25     0.050000
# 26     0.042500
# 27     0.040000
# 28     0.037500
# 29     0.037500
# ..          ...
# 50     0.054589
# 51     0.047088
# 52     0.043220
# 53     0.041432
# 54     0.041286
# 55     0.039095
# 56     0.037402
# 57     0.037347
# 58     0.037125
# 59     0.034681
# 60     0.045714
# 61     0.032520
# 62     0.032262
# 63     0.030675
# 64     0.029524
# 65     0.029008
# 66     0.028571
# 67     0.028299
# 68     0.028056
# 69     0.024352
# 70     0.153333
# 71     0.136667
# 72     0.105556
# 73     0.046667
# 74     0.043333
# 75     0.040000
# 76     0.038810
# 77     0.029167
# 78     0.028889
# 79     0.028889
#
# [80 rows x 3 columns]

# %%
split_group = df.groupby("Comparison")
data = [split_group.get_group(x) for x in split_group.groups]
order = [2,6,0,4,3,7,1,5]
ordered_data = []
for i in order:
    display(data[i])
    ordered_data.append(data[i])
# Out:
#         Comparison                                  Feature  Importance
# 0  T2_PvL_(BA+WSG)                  s_Lactobacillus_reuteri         0.24
# 1  T2_PvL_(BA+WSG)                Lithocholic acid (NIST14)         0.10
# 2  T2_PvL_(BA+WSG)                s_Akkermansia_muciniphila         0.08
# 3  T2_PvL_(BA+WSG)   3_-Hydroxy-5-cholenoic acid (NIST14).1         0.06
# 4  T2_PvL_(BA+WSG)                        Ursocholic acid.3         0.05
# 5  T2_PvL_(BA+WSG)   3_-Hydroxy-5-cholenoic acid (NIST14).4         0.04
# 6  T2_PvL_(BA+WSG)                            Cholic acid.7         0.03
# 7  T2_PvL_(BA+WSG)            s_Parabacteroides_goldsteinii         0.03
# 8  T2_PvL_(BA+WSG)                s_Lactobacillus_johnsonii         0.03
# 9  T2_PvL_(BA+WSG)                    Chenodeoxycholic acid         0.03
#          Comparison                                     Feature  Importance
# 40  T5_PvL_(BA+WSG)      s_Candidatus_Arthromitus_sp._SFB-mouse        0.245
# 41  T5_PvL_(BA+WSG)   s_Candidatus_Arthromitus_sp._SFB-mouse-NL        0.085
# 42  T5_PvL_(BA+WSG)               s_Parabacteroides_goldsteinii        0.075
# 43  T5_PvL_(BA+WSG)                     s_Lactobacillus_reuteri        0.065
# 44  T5_PvL_(BA+WSG)          12-Ketodeoxycholic acid (NIST14).2        0.065
# 45  T5_PvL_(BA+WSG)                     s_Lactobacillus_gasseri        0.060
# 46  T5_PvL_(BA+WSG)                    Cholic acid methyl ester        0.050
# 47  T5_PvL_(BA+WSG)              s_Paenibacillus_sp._IHB_B_3084        0.040
# 48  T5_PvL_(BA+WSG)                   s_Akkermansia_muciniphila        0.040
# 49  T5_PvL_(BA+WSG)                  Cholic acid methyl ester.2        0.030
#            Comparison                                 Feature  Importance
# 20  T2_LvCoL_(BA+WSG)  3_-Hydroxy-5-cholenoic acid (NIST14).1       0.1150
# 21  T2_LvCoL_(BA+WSG)                 Cholic acid (NIST14).19       0.1075
# 22  T2_LvCoL_(BA+WSG)               Lithocholic acid (NIST14)       0.0950
# 23  T2_LvCoL_(BA+WSG)                 Cholic acid (NIST14).17       0.0650
# 24  T2_LvCoL_(BA+WSG)                Cholic acid methyl ester       0.0550
# 25  T2_LvCoL_(BA+WSG)                s_Lactobacillus_animalis       0.0500
# 26  T2_LvCoL_(BA+WSG)                 s_Lactobacillus_murinus       0.0425
# 27  T2_LvCoL_(BA+WSG)    Tauroursodeoxycholic acid (NIST14).1       0.0400
# 28  T2_LvCoL_(BA+WSG)                 Cholic acid (NIST14).14       0.0375
# 29  T2_LvCoL_(BA+WSG)                      Taurocholic acid.1       0.0375
#            Comparison                          Feature  Importance
# 60  T5_LvCoL_(BA+WSG)             _-Muricholic acid.13     0.045714
# 61  T5_LvCoL_(BA+WSG)   s_Bifidobacterium_pseudolongum     0.032520
# 62  T5_LvCoL_(BA+WSG)              s_Borrelia_anserina     0.032262
# 63  T5_LvCoL_(BA+WSG)         s_Entomoplasma_freundtii     0.030675
# 64  T5_LvCoL_(BA+WSG)          _-Hyodeoxycholic acid.7     0.029524
# 65  T5_LvCoL_(BA+WSG)       s_Corynebacterium_uterequi     0.029008
# 66  T5_LvCoL_(BA+WSG)        s_Lactobacillus_johnsonii     0.028571
# 67  T5_LvCoL_(BA+WSG)     s_Pseudobutyrivibrio_ruminis     0.028299
# 68  T5_LvCoL_(BA+WSG)          s_Lactobacillus_gasseri     0.028056
# 69  T5_LvCoL_(BA+WSG)         Cholic acid methyl ester     0.024352
#                   Comparison                                  Feature  \
# 10  T2_PvL_(Metabolomic+WSG)                                 Bacosine
# 11  T2_PvL_(Metabolomic+WSG)              Oleanolic acid methyl ester
# 12  T2_PvL_(Metabolomic+WSG)   4-dihydroxyheptadec-16-en-2-yl acetate
# 13  T2_PvL_(Metabolomic+WSG)                s_Akkermansia_muciniphila
# 14  T2_PvL_(Metabolomic+WSG)                  s_Lactobacillus_gasseri
# 15  T2_PvL_(Metabolomic+WSG)                  s_Lactobacillus_murinus
# 16  T2_PvL_(Metabolomic+WSG)                s_Lactobacillus_johnsonii
# 17  T2_PvL_(Metabolomic+WSG)       cis-581114-Eicosatetraenoic acid.1
# 18  T2_PvL_(Metabolomic+WSG)                        Urobilin (NIST14)
# 19  T2_PvL_(Metabolomic+WSG)                                   Phenol
#
#     Importance
# 10     0.075715
# 11     0.058373
# 12     0.056586
# 13     0.042088
# 14     0.041901
# 15     0.039571
# 16     0.037748
# 17     0.032912
# 18     0.032727
# 19     0.030448
#                   Comparison                                     Feature  \
# 50  T5_PvL_(Metabolomic+WSG)                     s_Lactobacillus_gasseri
# 51  T5_PvL_(Metabolomic+WSG)                                    Bacosine
# 52  T5_PvL_(Metabolomic+WSG)                     s_Lactobacillus_reuteri
# 53  T5_PvL_(Metabolomic+WSG)                    s_Entomoplasma_freundtii
# 54  T5_PvL_(Metabolomic+WSG)               s_Parabacteroides_goldsteinii
# 55  T5_PvL_(Metabolomic+WSG)      s_Candidatus_Arthromitus_sp._SFB-mouse
# 56  T5_PvL_(Metabolomic+WSG)                   s_Lactobacillus_johnsonii
# 57  T5_PvL_(Metabolomic+WSG)                        s_Vibrio_sp._2521-89
# 58  T5_PvL_(Metabolomic+WSG)              s_Bifidobacterium_pseudolongum
# 59  T5_PvL_(Metabolomic+WSG)   s_Candidatus_Arthromitus_sp._SFB-mouse-NL
#
#     Importance
# 50     0.054589
# 51     0.047088
# 52     0.043220
# 53     0.041432
# 54     0.041286
# 55     0.039095
# 56     0.037402
# 57     0.037347
# 58     0.037125
# 59     0.034681
#                     Comparison                                   Feature  \
# 30  T2_LvCoL_(Metabolomic+WSG)                   phosphocholine (NIST14)
# 31  T2_LvCoL_(Metabolomic+WSG)               Oleanolic acid methyl ester
# 32  T2_LvCoL_(Metabolomic+WSG)        cis-581114-Eicosatetraenoic acid.1
# 33  T2_LvCoL_(Metabolomic+WSG)                         Urobilin (NIST14)
# 34  T2_LvCoL_(Metabolomic+WSG)                 phosphocholine (NIST14).2
# 35  T2_LvCoL_(Metabolomic+WSG)   1-Palmitoyl-sn-glycero-3-phosphocholine
# 36  T2_LvCoL_(Metabolomic+WSG)                           Phytomonic acid
# 37  T2_LvCoL_(Metabolomic+WSG)                 phosphocholine (NIST14).4
# 38  T2_LvCoL_(Metabolomic+WSG)   1-Hexadecyl-sn-glycero-3-phosphocholine
# 39  T2_LvCoL_(Metabolomic+WSG)                                  Urobilin
#
#     Importance
# 30     0.126667
# 31     0.110000
# 32     0.106667
# 33     0.100000
# 34     0.093333
# 35     0.076667
# 36     0.060000
# 37     0.040000
# 38     0.040000
# 39     0.036667
#                     Comparison                                   Feature  \
# 70  T5_LvCoL_(Metabolomic+WSG)                s_Corynebacterium_uterequi
# 71  T5_LvCoL_(Metabolomic+WSG)   1-Palmitoyl-sn-glycero-3-phosphocholine
# 72  T5_LvCoL_(Metabolomic+WSG)        cis-581114-Eicosatetraenoic acid.1
# 73  T5_LvCoL_(Metabolomic+WSG)           1-Phenanthrenecarboxylic acid.1
# 74  T5_LvCoL_(Metabolomic+WSG)                               Hederagenin
# 75  T5_LvCoL_(Metabolomic+WSG)                        Sumaresinolic acid
# 76  T5_LvCoL_(Metabolomic+WSG)                Linoleic acid methyl ester
# 77  T5_LvCoL_(Metabolomic+WSG)                   s_Lactobacillus_gasseri
# 78  T5_LvCoL_(Metabolomic+WSG)              phosphoethanolamine (NIST14)
# 79  T5_LvCoL_(Metabolomic+WSG)                       3-Hydroxykynurenine
#
#     Importance
# 70     0.153333
# 71     0.136667
# 72     0.105556
# 73     0.046667
# 74     0.043333
# 75     0.040000
# 76     0.038810
# 77     0.029167
# 78     0.028889
# 79     0.028889

# %%
fig, axs = plt.subplots(ncols=2, nrows=4, figsize=(20, 15))
fig.subplots_adjust(hspace=.3,wspace=0.65)
Titles = ["BA+WGS P/LET Week 2", "BA+WGS P/LET Week 5", "BA+WGS LETch/LET Week 2", "BA+WGS LETch/LET Week 5", 
          "Metabolite+WGS P/LET Week 2", "Metabolite+WGS P/LET Week 5", "Metabolite+WGS LETch/LET Week 2", "Metabolite+WGS LETch/LET Week 5"]

for i, graph in enumerate(ordered_data):
    graph.plot(kind='barh', x ="Feature", legend=False, ax=axs[i//2][i%2])
    axs[i//2][i%2].set_title(Titles[i])
    axs[i//2][i%2].invert_yaxis()
    axs[i//2][i%2].set_ylabel("")
    
fig.text(0.45, 0.087, 'Importance', ha='center', size = 20)
fig.text(-.045, 0.5, 'Features', va='center', rotation='vertical', size = 20)   
fig.align_ylabels(axs[:, 0])
fig.align_ylabels(axs[:, 1])
plt.savefig("RF_Features_importance.pdf",format='pdf', dpi=650,bbox_inches = "tight")
