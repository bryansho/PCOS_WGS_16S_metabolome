# %%
import pandas as pd
from skbio.diversity import beta_diversity
from skbio.stats.ordination import pcoa
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
from skbio.stats.distance import anosim
from skbio.stats.distance import permanova
import numpy as np

# %%
df5 = pd.read_csv('t5.tsv', sep='\t',index_col=0)
ids5 = list(df5.columns.values)
df5 = df5.T
data5 = df5.values.tolist()

# %%
bc_dm5 = beta_diversity("braycurtis", data5, ids5)

# %%
bc_dm5

# %%
bc_pcoa5 = pcoa(bc_dm5)
# Out:
# /home/basilin/anaconda3/envs/qiime2020/lib/python3.6/site-packages/skbio/stats/ordination/_principal_coordinate_analysis.py:152: RuntimeWarning: The result contains negative eigenvalues. Please compare their magnitude with the magnitude of some of the largest positive eigenvalues. If the negative ones are smaller, it's probably safe to ignore them, but if they are large in magnitude, the results won't be useful. See the Notes section for more details. The smallest eigenvalue is -0.0023818235703807595 and the largest is 0.8051428690968223.
#   RuntimeWarning

# %%
mapping = pd.read_csv('mapping_file_Treat.tsv', sep="\t", index_col=0)
mapping
# Out:
#         Week Category
# OTUID
# 570.T0     0  Placebo
# 570.T1     1  Placebo
# 570.T2     2  Placebo
# 570.T3     3  Placebo
# 570.T4     4  Placebo
# ...      ...      ...
# 603.T1     1     Co-L
# 603.T2     2     Co-L
# 603.T3     3     Co-L
# 603.T4     4     Co-L
# 603.T5     5     Co-L
#
# [192 rows x 2 columns]

# %%
mapping_time2 = mapping[mapping.Week == 2]
mapping_time5 = mapping[mapping.Week == 5]

# %%
mapping_time2 = mapping_time2.drop("Week", axis=1)
mapping_time5 = mapping_time5.drop("Week", axis=1)

# %% [markdown]
# ## Time 5 16s

# %%
ax5 = bc_pcoa5.plot(mapping_time5, 'Category', axis_labels=('PC 1', 'PC 2', 'PC 3'), title='T2', cmap='Accent', s=50)
ax5.set_size_inches(12, 8)

# %%
results5_an = anosim(bc_dm5, mapping_time5, column='Category', permutations=999)
results5_an
# Out:
# method name                  ANOSIM
# test statistic name               R
# sample size                      28
# number of groups                  4
# test statistic           -0.0240522
# p-value                       0.663
# number of permutations          999
# Name: ANOSIM results, dtype: object

# %%
results5_p = permanova(bc_dm5, mapping_time5, column='Category', permutations=999)
results5_p
# Out:
# method name               PERMANOVA
# test statistic name        pseudo-F
# sample size                      28
# number of groups                  4
# test statistic             0.894974
# p-value                       0.655
# number of permutations          999
# Name: PERMANOVA results, dtype: object

# %% [markdown]
# ## Time 2 16s

# %%
df5 = pd.read_csv('t2.tsv', sep='\t',index_col=0)
ids5 = list(df5.columns.values)
df5 = df5.T
data5 = df5.values.tolist()

# %%
df5
# Out:
# OTUID   1bbef1070bedf0db507fb6c7b5c28fff  54843b106b5061dc17ca8f371d357b44  \
# 570.T2                               878                                 0
# 571.T2                               191                               189
# 572.T2                               109                               156
# 573.T2                               249                               237
# 574.T2                               693                               617
# 575.T2                               317                               320
# 576.T2                               495                               384
# 577.T2                               129                               142
# 578.T2                               471                               494
# 580.T2                                44                                66
# 581.T2                                31                                45
# 582.T2                                62                                85
# 583.T2                               221                               251
# 584.T2                               225                               261
# 585.T2                                 0                                 0
# 586.T2                               414                               392
# 588.T2                               298                               296
# 589.T2                               197                               254
# 590.T2                               405                               361
# 592.T2                               511                               396
# 593.T2                               109                                85
# 594.T2                               121                                72
# 595.T2                              1271                               857
# 596.T2                               405                               349
# 597.T2                               291                               275
# 598.T2                               869                               609
# 599.T2                               136                               117
# 600.T2                              1275                              1068
# 601.T2                               954                              1139
# 602.T2                              1140                               996
# 603.T2                               753                               632
#
# OTUID   ff3c4e848cb548750221af3deb5389dc  646c18c31a1f6154773b7b8e64b5c658  \
# 570.T2                                 0                               835
# 571.T2                               123                               144
# 572.T2                               172                               137
# 573.T2                               141                               182
# 574.T2                               364                               426
# 575.T2                               216                               223
# 576.T2                               331                               380
# 577.T2                               133                               237
# 578.T2                               340                               336
# 580.T2                                38                                38
# 581.T2                                33                                39
# 582.T2                                97                                66
# 583.T2                               205                               215
# 584.T2                               202                               238
# 585.T2                               178                               185
# 586.T2                                 0                                 0
# 588.T2                               310                               326
# 589.T2                               196                               180
# 590.T2                               299                               254
# 592.T2                               209                               220
# 593.T2                                52                                57
# 594.T2                                54                               103
# 595.T2                                 0                               619
# 596.T2                               201                               215
# 597.T2                               218                               188
# 598.T2                               389                               412
# 599.T2                                67                                72
# 600.T2                               728                               642
# 601.T2                               820                               800
# 602.T2                               813                               778
# 603.T2                               665                               594
#
# OTUID   5171cbfbcd1781f0d7e7a7bdb94fb126  74803c74b50392f83753468b9235c931  \
# 570.T2                               807                                 0
# 571.T2                               164                               136
# 572.T2                               142                               167
# 573.T2                               189                               206
# 574.T2                               531                               465
# 575.T2                               211                               237
# 576.T2                               435                               366
# 577.T2                               110                               180
# 578.T2                               286                               299
# 580.T2                                 0                                54
# 581.T2                                 0                                37
# 582.T2                                69                                61
# 583.T2                               197                               191
# 584.T2                               218                               204
# 585.T2                                 0                                 0
# 586.T2                                 0                                 0
# 588.T2                               251                               276
# 589.T2                               178                               198
# 590.T2                               296                               320
# 592.T2                               232                               224
# 593.T2                                70                                57
# 594.T2                                80                                72
# 595.T2                               637                               523
# 596.T2                               252                               251
# 597.T2                               190                               184
# 598.T2                               515                               439
# 599.T2                                83                                84
# 600.T2                               882                               801
# 601.T2                               687                               746
# 602.T2                               815                               858
# 603.T2                               610                               636
#
# OTUID   2a2bbfefccc170850029ee0b903a7301  b90340baf132ddf80f4a342d544f1b03  \
# 570.T2                                 0                                 0
# 571.T2                                74                               112
# 572.T2                               174                               112
# 573.T2                               117                               131
# 574.T2                               188                               305
# 575.T2                               129                               172
# 576.T2                               242                               291
# 577.T2                                92                                99
# 578.T2                               236                               248
# 580.T2                                 0                                 0
# 581.T2                                35                                41
# 582.T2                                60                                64
# 583.T2                               267                               212
# 584.T2                               179                               183
# 585.T2                               189                                 0
# 586.T2                                 0                                 0
# 588.T2                               290                               269
# 589.T2                               145                               133
# 590.T2                               186                               236
# 592.T2                               160                               213
# 593.T2                                38                                61
# 594.T2                                36                                61
# 595.T2                                 0                               501
# 596.T2                               120                               188
# 597.T2                               154                               167
# 598.T2                               258                               351
# 599.T2                                52                                76
# 600.T2                               430                               641
# 601.T2                               662                               713
# 602.T2                               660                               751
# 603.T2                               563                               530
#
# OTUID   e305ca72b43b91c7a701c947a71ef4b7  ad4f3211c1c7fd39e69c4a22600a9475  \
# 570.T2                                 0                               520
# 571.T2                                79                               133
# 572.T2                               135                               108
# 573.T2                               117                               151
# 574.T2                               173                               341
# 575.T2                               131                               174
# 576.T2                               227                               347
# 577.T2                                98                               101
# 578.T2                               252                               274
# 580.T2                                26                                33
# 581.T2                                26                                31
# 582.T2                                65                                46
# 583.T2                               244                               173
# 584.T2                               170                               165
# 585.T2                                 0                                 0
# 586.T2                                 0                                 0
# 588.T2                               296                               239
# 589.T2                               147                               139
# 590.T2                               174                               233
# 592.T2                               164                               255
# 593.T2                                50                                67
# 594.T2                                54                                77
# 595.T2                                 0                               460
# 596.T2                               121                               208
# 597.T2                               154                               176
# 598.T2                               216                               437
# 599.T2                                63                                74
# 600.T2                               469                               712
# 601.T2                               655                               623
# 602.T2                               637                               817
# 603.T2                               546                               506
#
# OTUID   ...  f98d979df04d330a67fb4e5b98ca104d  \
# 570.T2  ...                                 0
# 571.T2  ...                                 0
# 572.T2  ...                                 0
# 573.T2  ...                                 0
# 574.T2  ...                                82
# 575.T2  ...                                 0
# 576.T2  ...                                56
# 577.T2  ...                                37
# 578.T2  ...                                 0
# 580.T2  ...                                 0
# 581.T2  ...                                 0
# 582.T2  ...                                 0
# 583.T2  ...                                 0
# 584.T2  ...                                 0
# 585.T2  ...                                95
# 586.T2  ...                                70
# 588.T2  ...                                 0
# 589.T2  ...                                 0
# 590.T2  ...                                 0
# 592.T2  ...                                 0
# 593.T2  ...                                 0
# 594.T2  ...                                 0
# 595.T2  ...                                 0
# 596.T2  ...                                 0
# 597.T2  ...                                 0
# 598.T2  ...                                 0
# 599.T2  ...                                 0
# 600.T2  ...                                46
# 601.T2  ...                                98
# 602.T2  ...                                50
# 603.T2  ...                                87
#
# OTUID   689c12390c09b9a29cf4fb872b49edd9  fb4ab06d1dfa87af3bbfa3cdfa43065e  \
# 570.T2                                 0                                 0
# 571.T2                                 0                                 0
# 572.T2                                 0                                46
# 573.T2                                 0                                 0
# 574.T2                                 0                                 0
# 575.T2                               106                                 0
# 576.T2                                 0                                 0
# 577.T2                                 0                                 0
# 578.T2                                 0                                 0
# 580.T2                                 0                                 0
# 581.T2                                 0                                 0
# 582.T2                                 0                                 0
# 583.T2                                 0                                 0
# 584.T2                                 0                                 0
# 585.T2                                 0                                 0
# 586.T2                                66                                 0
# 588.T2                                 0                                35
# 589.T2                                 0                                 0
# 590.T2                                86                                 0
# 592.T2                                 0                                 0
# 593.T2                                 0                                 0
# 594.T2                                 0                                 0
# 595.T2                                 0                                 0
# 596.T2                                 0                                 0
# 597.T2                                 0                                 0
# 598.T2                                70                                 0
# 599.T2                                 0                                 0
# 600.T2                                47                                 0
# 601.T2                                 0                                 0
# 602.T2                                79                                71
# 603.T2                                80                                82
#
# OTUID   5b11801bb8adfc9ff5e1a1960d96bc16  4b28010a343b8f259cd4e8f4c91672c8  \
# 570.T2                                 0                                99
# 571.T2                                 0                                 0
# 572.T2                                 0                                 0
# 573.T2                                 0                                 0
# 574.T2                               238                                 0
# 575.T2                                 0                                 0
# 576.T2                               105                                 0
# 577.T2                                 0                                 0
# 578.T2                               170                                 0
# 580.T2                                 0                                 0
# 581.T2                                 0                                 0
# 582.T2                                 0                                 0
# 583.T2                                25                                46
# 584.T2                                97                               122
# 585.T2                                 0                                 0
# 586.T2                                 0                                 0
# 588.T2                                 0                                 0
# 589.T2                                 0                                 0
# 590.T2                                 0                                 0
# 592.T2                                 0                                 0
# 593.T2                                 0                                 0
# 594.T2                                66                                 0
# 595.T2                                 0                                 0
# 596.T2                                 0                                98
# 597.T2                                 0                                 0
# 598.T2                                 0                                 0
# 599.T2                                 0                                 0
# 600.T2                                58                                33
# 601.T2                                66                                39
# 602.T2                                52                                44
# 603.T2                                 0                                61
#
# OTUID   c00da10f7b1c5103b343824f9ff5937b  f969f77024f652bdd33ca8aa4d348a91  \
# 570.T2                                 0                                79
# 571.T2                                 0                                 0
# 572.T2                                 0                                 0
# 573.T2                                 0                                 0
# 574.T2                               137                                 0
# 575.T2                                 0                                 0
# 576.T2                                34                                 0
# 577.T2                                 0                                 0
# 578.T2                                44                                 0
# 580.T2                                 0                                 0
# 581.T2                                 0                                 0
# 582.T2                                63                               135
# 583.T2                                34                                31
# 584.T2                                 0                                 0
# 585.T2                                 0                                 0
# 586.T2                                 0                                 0
# 588.T2                                23                                 0
# 589.T2                                 0                                 0
# 590.T2                               135                                 0
# 592.T2                                 0                                 0
# 593.T2                                 0                                 0
# 594.T2                                 0                                45
# 595.T2                                 0                                 0
# 596.T2                                 0                                 0
# 597.T2                                 0                                 0
# 598.T2                                 0                                 0
# 599.T2                                 0                                 0
# 600.T2                                70                                32
# 601.T2                                92                                42
# 602.T2                                98                                64
# 603.T2                                87                                46
#
# OTUID   7db509e298401edfc42514f0e35a48bd  31104eba47b7c647b4712e33dfeb786b  \
# 570.T2                                 0                                 0
# 571.T2                                 0                                 0
# 572.T2                                 0                                 0
# 573.T2                                 0                                 0
# 574.T2                                74                                 0
# 575.T2                                62                                 0
# 576.T2                                 0                                 0
# 577.T2                                 0                                 0
# 578.T2                                 0                                 0
# 580.T2                                 0                                 0
# 581.T2                                 0                                 0
# 582.T2                                 0                                 0
# 583.T2                                 0                                 0
# 584.T2                                 0                                 0
# 585.T2                                 0                                 0
# 586.T2                                 0                                 0
# 588.T2                                 0                                 0
# 589.T2                                 0                                 0
# 590.T2                                39                                 0
# 592.T2                                 0                                 0
# 593.T2                                 0                                 0
# 594.T2                                75                                 0
# 595.T2                                 0                                 0
# 596.T2                                 0                                 0
# 597.T2                                 0                                 0
# 598.T2                                 0                                 0
# 599.T2                                 0                               104
# 600.T2                                77                                35
# 601.T2                                52                                45
# 602.T2                                69                                75
# 603.T2                                65                               110
#
# OTUID   e2ef7cb559b4796a5ecbf979b2c6c47c
# 570.T2                                 0
# 571.T2                                 0
# 572.T2                                 0
# 573.T2                                69
# 574.T2                                29
# 575.T2                                 0
# 576.T2                                24
# 577.T2                                 0
# 578.T2                                 0
# 580.T2                                 0
# 581.T2                                 0
# 582.T2                                 0
# 583.T2                                88
# 584.T2                                 0
# 585.T2                                 0
# 586.T2                                 0
# 588.T2                                 0
# 589.T2                                 0
# 590.T2                                 0
# 592.T2                                 0
# 593.T2                                 0
# 594.T2                                 0
# 595.T2                                 0
# 596.T2                                 0
# 597.T2                                 0
# 598.T2                                 0
# 599.T2                                 0
# 600.T2                                 0
# 601.T2                                51
# 602.T2                                59
# 603.T2                                76
#
# [31 rows x 192 columns]

# %%
bc_dm5 = beta_diversity("braycurtis", data5, ids5)

# %%
bc_dm5

# %%
bc_pcoa5 = pcoa(bc_dm5)
# Out:
# /home/basilin/anaconda3/envs/qiime2020/lib/python3.6/site-packages/skbio/stats/ordination/_principal_coordinate_analysis.py:152: RuntimeWarning: The result contains negative eigenvalues. Please compare their magnitude with the magnitude of some of the largest positive eigenvalues. If the negative ones are smaller, it's probably safe to ignore them, but if they are large in magnitude, the results won't be useful. See the Notes section for more details. The smallest eigenvalue is -0.0017379732546549745 and the largest is 1.3635099459202018.
#   RuntimeWarning

# %%
ax5 = bc_pcoa5.plot(mapping_time2, 'Category', axis_labels=('PC 1', 'PC 2', 'PC 3'), title='T2', cmap='Accent', s=50)
ax5.set_size_inches(12, 8)

# %%
results5_an = anosim(bc_dm5, mapping_time2, column='Category', permutations=999)
results5_an
# Out:
# method name                 ANOSIM
# test statistic name              R
# sample size                     31
# number of groups                 4
# test statistic            0.063545
# p-value                      0.065
# number of permutations         999
# Name: ANOSIM results, dtype: object

# %%
results5_p = permanova(bc_dm5, mapping_time2, column='Category', permutations=999)
results5_p
# Out:
# method name               PERMANOVA
# test statistic name        pseudo-F
# sample size                      31
# number of groups                  4
# test statistic              1.32368
# p-value                       0.056
# number of permutations          999
# Name: PERMANOVA results, dtype: object
