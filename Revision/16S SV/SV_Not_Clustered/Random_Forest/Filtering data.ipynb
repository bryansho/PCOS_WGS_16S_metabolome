# %%
library(ggplot2)
library(vegan)
library(dplyr)
library(scales)
library(grid)
library(reshape2)
library(phyloseq)
#install.packages("ggfortify")
library('ggfortify')
packageVersion('ggfortify')
# Out:
# Loading required package: permute
# Loading required package: lattice
# This is vegan 2.5-6
#
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
# [1] ‘0.4.8’

# %%
table<-read.csv("denovo_all_time.csv",sep = ',',check.names=FALSE)
meta_t<-read.csv("mapping_file_cohousing2018_treat.tsv",sep = '\t',check.names=FALSE)

# %%
table
# Out:
#     SampleID denovo19478     denovo31970 denovo43926     denovo52359
# 1   573.T3   19              0           0               5
# 2   598.T1   8               1           0               1
# 3   589.T2   0               0           0               14
# 4   593.T3   19              0           19              1
# 5   586.T2   1               1           0               0
# 6   590.T3   6               0           1               19
# 7   601.T1   2               0           0               9
# 8   572.T1   6               0           0               1
# 9   597.T3   1               0           0               1
# 10  577.T3   18              0           0               3
# 11  595.T4   3               0           10              9
# 12  586.T0   1               0           16              1
# 13  574.T1   8               0           4               6
# 14  572.T5   7               16          8               1
# 15  578.T4   6               7           1               0
# ...

# %%
all <- merge(table,meta_t,by="SampleID")
#time2$Week <- NULL
all
# Out:
#     SampleID denovo19478 denovo31970 denovo43926 denovo52359 denovo79770
# 1   570.T0   0           0           0           0           0
# 2   570.T1   2           1           2           3           3
# 3   570.T2   31          1           2           28          0
# 4   570.T3   423         0           2           75          4
# 5   570.T4   3           0           0           0           0
# 6   570.T5   49          0           0           24          1
# 7   571.T0   7           1           4           1           0
# 8   571.T1   4           2           2           0           21
# 9   571.T2   1           8           1           0           10
# 10  571.T3   16          4           3           0           1
# 11  571.T4   183         1           10          0           10
# 12  571.T5   364         49          0           1           1
# 13  572.T0   1           0           2           3           8
# 14  572.T1   6           0           0           1           18
# ...

# %%
time2 <- subset(all, Week == '2')
time5 <- subset(all, Week == '5')

# %%
#time2_pvl <- subset(all, Category == 'Placebo' | Category == 'Letrozole')
#time2_lvcol <- subset(all, Category == 'Co-L' | Category == 'Letrozole')
time5_pvl <- subset(all, Category == 'Placebo' | Category == 'Letrozole')
time5_lvcol <- subset(all, Category == 'Co-L' | Category == 'Letrozole')
time5_lvcol
# Out:
#    SampleID Urobilin Sumaresinolic acid Urobilin (NIST14) Urobilin (NIST14).1
# 9  578.T5       0        0                  0                0
# 10 580.T5    5245        0                  0             6703
# 11 581.T5   13247        0                  0                0
# 12 582.T5       0        0                  0                0
# 13 583.T5       0        0                  0                0
# 14 584.T5   18011    37491               8883                0
# 15 585.T5   24037     6618              11570                0
# 16 586.T5       0    23686                897                0
# 18 589.T5    6925        0                  0             3461
# 20 591.T5    6749        0               7232                0
# 22 593.T5       0        0                  0                0
# 24 595.T5       0     8185                664                0
# 26 597.T5       0        0               9566                0
# 28 599.T5   18289     3895              35457                0
# ...

# %%
write.table(time2, file='denovo_time2.tsv', quote=FALSE, sep='\t', col.names = TRUE, row.names = FALSE)
write.table(time5, file='denovo_time5.tsv', quote=FALSE, sep='\t', col.names = TRUE, row.names = FALSE)
#write.table(time2_lvcol, file='Known_no_BA_t2_lvcol.tsv', quote=FALSE, sep='\t', col.names = TRUE, row.names = FALSE)
#write.table(time5_lvcol, file='Known_no_BA_t5_lvcol.tsv', quote=FALSE, sep='\t', col.names = TRUE, row.names = FALSE)
