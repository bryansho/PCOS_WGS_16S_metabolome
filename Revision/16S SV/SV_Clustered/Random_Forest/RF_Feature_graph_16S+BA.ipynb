# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("RF_top_features.csv")
df
# Out:
#            Comparison                               Feature  Importance
# 0     T2_PvL_(BA+16s)  3β-Hydroxy-5-cholenoic acid (NIST14)    0.103636
# 1     T2_PvL_(BA+16s)             Lithocholic acid (NIST14)    0.100000
# 2     T2_PvL_(BA+16s)                  f__Ruminococcaceae.1    0.073939
# 3     T2_PvL_(BA+16s)               β-Hyodeoxycholic acid.7    0.073333
# 4     T2_PvL_(BA+16s)                    f__Lachnospiraceae    0.067273
# 5     T2_PvL_(BA+16s)                     g__Oscillospira.4    0.059394
# 6     T2_PvL_(BA+16s)                      g__Lactobacillus    0.056970
# 7     T2_PvL_(BA+16s)                        g__Odoribacter    0.045455
# 8     T2_PvL_(BA+16s)           Deoxycholic acid (NIST14).1    0.032121
# 9     T2_PvL_(BA+16s)                       g__Anaerostipes    0.027273
# 10  T2_LvCoL_(BA+16s)                Cholic acid (NIST14).5    0.085271
# 11  T2_LvCoL_(BA+16s)               Cholic acid (NIST14).14    0.077519
# 12  T2_LvCoL_(BA+16s)  Tauroursodeoxycholic acid (NIST14).1    0.077519
# 13  T2_LvCoL_(BA+16s)             Lithocholic acid (NIST14)    0.069767
# 14  T2_LvCoL_(BA+16s)    α-Hyodeoxycholic acid methyl ester    0.069767
# 15  T2_LvCoL_(BA+16s)                     Ursocholic acid.3    0.062016
# 16  T2_LvCoL_(BA+16s)                  β-Muricholic acid.11    0.054264
# 17  T2_LvCoL_(BA+16s)                    Taurocholic acid.3    0.054264
# 18  T2_LvCoL_(BA+16s)    Tauroursodeoxycholic acid (NIST14)    0.031008
# 19  T2_LvCoL_(BA+16s)               Cholic acid (NIST14).17    0.031008
# 20    T5_PvL_(BA+16s)    12-Ketodeoxycholic acid (NIST14).2    0.172619
# 21    T5_PvL_(BA+16s)                    f__Rikenellaceae.1    0.111976
# 22    T5_PvL_(BA+16s)                 f__Lachnospiraceae.10    0.102667
# 23    T5_PvL_(BA+16s)                        g__Akkermansia    0.074000
# 24    T5_PvL_(BA+16s)                     g__Oscillospira.2    0.058667
# 25    T5_PvL_(BA+16s)                  f__Lachnospiraceae.9    0.056667
# 26    T5_PvL_(BA+16s)               β-Hyodeoxycholic acid.7    0.037976
# 27    T5_PvL_(BA+16s)           Deoxycholic acid (NIST14).2    0.035000
# 28    T5_PvL_(BA+16s)                     g__[Ruminococcus]    0.025667
# 29    T5_PvL_(BA+16s)                      f__Rikenellaceae    0.021000
# 30  T5_LvCoL_(BA+16s)                    g__Lactobacillus.1    0.083799
# 31  T5_LvCoL_(BA+16s)           Deoxycholic acid (NIST14).5    0.070531
# 32  T5_LvCoL_(BA+16s)                            f__S24-7.3    0.067039
# 33  T5_LvCoL_(BA+16s)                  f__Ruminococcaceae.1    0.061453
# 34  T5_LvCoL_(BA+16s)                 f__Lachnospiraceae.11    0.061453
# 35  T5_LvCoL_(BA+16s)                  f__Coriobacteriaceae    0.055866
# 36  T5_LvCoL_(BA+16s)               Cholic acid (NIST14).14    0.050279
# 37  T5_LvCoL_(BA+16s)                  f__Lachnospiraceae.9    0.039106
# 38  T5_LvCoL_(BA+16s)                  β-Muricholic acid.11    0.033520
# 39  T5_LvCoL_(BA+16s)                   γ-Muricholic acid.6    0.027933

# %%
split_group = df.groupby("Comparison")
data = [split_group.get_group(x) for x in split_group.groups]
order = [1,3,0,2]
ordered_data = []
for i in order:
    display(data[i])
    ordered_data.append(data[i])
# Out:
#         Comparison                               Feature  Importance
# 0  T2_PvL_(BA+16s)  3β-Hydroxy-5-cholenoic acid (NIST14)    0.103636
# 1  T2_PvL_(BA+16s)             Lithocholic acid (NIST14)    0.100000
# 2  T2_PvL_(BA+16s)                  f__Ruminococcaceae.1    0.073939
# 3  T2_PvL_(BA+16s)               β-Hyodeoxycholic acid.7    0.073333
# 4  T2_PvL_(BA+16s)                    f__Lachnospiraceae    0.067273
# 5  T2_PvL_(BA+16s)                     g__Oscillospira.4    0.059394
# 6  T2_PvL_(BA+16s)                      g__Lactobacillus    0.056970
# 7  T2_PvL_(BA+16s)                        g__Odoribacter    0.045455
# 8  T2_PvL_(BA+16s)           Deoxycholic acid (NIST14).1    0.032121
# 9  T2_PvL_(BA+16s)                       g__Anaerostipes    0.027273
#          Comparison                             Feature  Importance
# 20  T5_PvL_(BA+16s)  12-Ketodeoxycholic acid (NIST14).2    0.172619
# 21  T5_PvL_(BA+16s)                  f__Rikenellaceae.1    0.111976
# 22  T5_PvL_(BA+16s)               f__Lachnospiraceae.10    0.102667
# 23  T5_PvL_(BA+16s)                      g__Akkermansia    0.074000
# 24  T5_PvL_(BA+16s)                   g__Oscillospira.2    0.058667
# 25  T5_PvL_(BA+16s)                f__Lachnospiraceae.9    0.056667
# 26  T5_PvL_(BA+16s)             β-Hyodeoxycholic acid.7    0.037976
# 27  T5_PvL_(BA+16s)         Deoxycholic acid (NIST14).2    0.035000
# 28  T5_PvL_(BA+16s)                   g__[Ruminococcus]    0.025667
# 29  T5_PvL_(BA+16s)                    f__Rikenellaceae    0.021000
#            Comparison                               Feature  Importance
# 10  T2_LvCoL_(BA+16s)                Cholic acid (NIST14).5    0.085271
# 11  T2_LvCoL_(BA+16s)               Cholic acid (NIST14).14    0.077519
# 12  T2_LvCoL_(BA+16s)  Tauroursodeoxycholic acid (NIST14).1    0.077519
# 13  T2_LvCoL_(BA+16s)             Lithocholic acid (NIST14)    0.069767
# 14  T2_LvCoL_(BA+16s)    α-Hyodeoxycholic acid methyl ester    0.069767
# 15  T2_LvCoL_(BA+16s)                     Ursocholic acid.3    0.062016
# 16  T2_LvCoL_(BA+16s)                  β-Muricholic acid.11    0.054264
# 17  T2_LvCoL_(BA+16s)                    Taurocholic acid.3    0.054264
# 18  T2_LvCoL_(BA+16s)    Tauroursodeoxycholic acid (NIST14)    0.031008
# 19  T2_LvCoL_(BA+16s)               Cholic acid (NIST14).17    0.031008
#            Comparison                      Feature  Importance
# 30  T5_LvCoL_(BA+16s)           g__Lactobacillus.1    0.083799
# 31  T5_LvCoL_(BA+16s)  Deoxycholic acid (NIST14).5    0.070531
# 32  T5_LvCoL_(BA+16s)                   f__S24-7.3    0.067039
# 33  T5_LvCoL_(BA+16s)         f__Ruminococcaceae.1    0.061453
# 34  T5_LvCoL_(BA+16s)        f__Lachnospiraceae.11    0.061453
# 35  T5_LvCoL_(BA+16s)         f__Coriobacteriaceae    0.055866
# 36  T5_LvCoL_(BA+16s)      Cholic acid (NIST14).14    0.050279
# 37  T5_LvCoL_(BA+16s)         f__Lachnospiraceae.9    0.039106
# 38  T5_LvCoL_(BA+16s)         β-Muricholic acid.11    0.033520
# 39  T5_LvCoL_(BA+16s)          γ-Muricholic acid.6    0.027933

# %%
data
# Out:
# [           Comparison                               Feature  Importance
#  10  T2_LvCoL_(BA+16s)                Cholic acid (NIST14).5    0.085271
#  11  T2_LvCoL_(BA+16s)               Cholic acid (NIST14).14    0.077519
#  12  T2_LvCoL_(BA+16s)  Tauroursodeoxycholic acid (NIST14).1    0.077519
#  13  T2_LvCoL_(BA+16s)             Lithocholic acid (NIST14)    0.069767
#  14  T2_LvCoL_(BA+16s)    α-Hyodeoxycholic acid methyl ester    0.069767
#  15  T2_LvCoL_(BA+16s)                     Ursocholic acid.3    0.062016
#  16  T2_LvCoL_(BA+16s)                  β-Muricholic acid.11    0.054264
#  17  T2_LvCoL_(BA+16s)                    Taurocholic acid.3    0.054264
#  18  T2_LvCoL_(BA+16s)    Tauroursodeoxycholic acid (NIST14)    0.031008
#  19  T2_LvCoL_(BA+16s)               Cholic acid (NIST14).17    0.031008,
#          Comparison                               Feature  Importance
#  0  T2_PvL_(BA+16s)  3β-Hydroxy-5-cholenoic acid (NIST14)    0.103636
#  1  T2_PvL_(BA+16s)             Lithocholic acid (NIST14)    0.100000
#  2  T2_PvL_(BA+16s)                  f__Ruminococcaceae.1    0.073939
#  3  T2_PvL_(BA+16s)               β-Hyodeoxycholic acid.7    0.073333
#  4  T2_PvL_(BA+16s)                    f__Lachnospiraceae    0.067273
#  5  T2_PvL_(BA+16s)                     g__Oscillospira.4    0.059394
#  6  T2_PvL_(BA+16s)                      g__Lactobacillus    0.056970
#  7  T2_PvL_(BA+16s)                        g__Odoribacter    0.045455
#  8  T2_PvL_(BA+16s)           Deoxycholic acid (NIST14).1    0.032121
#  9  T2_PvL_(BA+16s)                       g__Anaerostipes    0.027273,
#             Comparison                      Feature  Importance
#  30  T5_LvCoL_(BA+16s)           g__Lactobacillus.1    0.083799
#  31  T5_LvCoL_(BA+16s)  Deoxycholic acid (NIST14).5    0.070531
#  32  T5_LvCoL_(BA+16s)                   f__S24-7.3    0.067039
#  33  T5_LvCoL_(BA+16s)         f__Ruminococcaceae.1    0.061453
#  34  T5_LvCoL_(BA+16s)        f__Lachnospiraceae.11    0.061453
#  35  T5_LvCoL_(BA+16s)         f__Coriobacteriaceae    0.055866
#  36  T5_LvCoL_(BA+16s)      Cholic acid (NIST14).14    0.050279
#  37  T5_LvCoL_(BA+16s)         f__Lachnospiraceae.9    0.039106
#  38  T5_LvCoL_(BA+16s)         β-Muricholic acid.11    0.033520
#  39  T5_LvCoL_(BA+16s)          γ-Muricholic acid.6    0.027933,
#           Comparison                             Feature  Importance
#  20  T5_PvL_(BA+16s)  12-Ketodeoxycholic acid (NIST14).2    0.172619
#  21  T5_PvL_(BA+16s)                  f__Rikenellaceae.1    0.111976
#  22  T5_PvL_(BA+16s)               f__Lachnospiraceae.10    0.102667
#  23  T5_PvL_(BA+16s)                      g__Akkermansia    0.074000
#  24  T5_PvL_(BA+16s)                   g__Oscillospira.2    0.058667
#  25  T5_PvL_(BA+16s)                f__Lachnospiraceae.9    0.056667
#  26  T5_PvL_(BA+16s)             β-Hyodeoxycholic acid.7    0.037976
#  27  T5_PvL_(BA+16s)         Deoxycholic acid (NIST14).2    0.035000
#  28  T5_PvL_(BA+16s)                   g__[Ruminococcus]    0.025667
#  29  T5_PvL_(BA+16s)                    f__Rikenellaceae    0.021000]

# %%
for i, graph in enumerate(ordered_data):
    print(i//2)
    print(i%2)
# Out:
# 0
# 0
# 0
# 1
# 1
# 0
# 1
# 1

# %%
fig, axs = plt.subplots(ncols=2, nrows=2, figsize=(20, 15))
fig.subplots_adjust(hspace=.3,wspace=0.65)
Titles = ["BA+16s P/LET Week 2", "BA+16s P/LET Week 5", "BA+16s LETch/LET Week 2", "BA+16s LETch/LET Week 5"]

for i, graph in enumerate(ordered_data):
    graph.plot(kind='barh', x ="Feature", legend=False,ax=axs[i//2][i%2])
    axs[i//2][i%2].set_title(Titles[i])
    axs[i//2][i%2].invert_yaxis()
    axs[i//2][i%2].set_ylabel("")
    axs[i//2][i%2].set_xlim([0, 0.176])
    
fig.text(0.45, 0.087, 'Importance', ha='center', size = 20)
fig.text(-.045, 0.5, 'Features', va='center', rotation='vertical', size = 20)   
fig.align_ylabels(axs[:, 0])
fig.align_ylabels(axs[:, 1])
plt.savefig("RF_Features_importance.pdf",format='pdf', dpi=650,bbox_inches = "tight")
