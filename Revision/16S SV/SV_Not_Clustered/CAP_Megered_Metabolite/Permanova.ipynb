# %%
import pandas as pd
from skbio.diversity import beta_diversity
from skbio.stats.ordination import pcoa
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
from skbio.stats.distance import anosim
from skbio.stats.distance import permanova
import numpy as np

# %%
df5 = pd.read_csv('t5_merged.tsv', sep='\t',index_col=0)
ids5 = list(df5.columns.values)
df5 = df5.T
data5 = df5.values.tolist()

# %%
bc_dm5 = beta_diversity("braycurtis", data5, ids5)

# %%
bc_dm5

# %%
bc_pcoa5 = pcoa(bc_dm5)
# Out:
# /home/basilin/anaconda3/envs/qiime2020/lib/python3.6/site-packages/skbio/stats/ordination/_principal_coordinate_analysis.py:152: RuntimeWarning: The result contains negative eigenvalues. Please compare their magnitude with the magnitude of some of the largest positive eigenvalues. If the negative ones are smaller, it's probably safe to ignore them, but if they are large in magnitude, the results won't be useful. See the Notes section for more details. The smallest eigenvalue is -0.07530627037143905 and the largest is 0.9824736143108247.
#   RuntimeWarning

# %%
mapping = pd.read_csv('mapping_file_Treat.tsv', sep="\t", index_col=0)
mapping
# Out:
#         Week Category
# OTUID
# 570.T0     0  Placebo
# 570.T1     1  Placebo
# 570.T2     2  Placebo
# 570.T3     3  Placebo
# 570.T4     4  Placebo
# ...      ...      ...
# 603.T1     1     Co-L
# 603.T2     2     Co-L
# 603.T3     3     Co-L
# 603.T4     4     Co-L
# 603.T5     5     Co-L
#
# [192 rows x 2 columns]

# %%
mapping_time2 = mapping[mapping.Week == 2]
mapping_time5 = mapping[mapping.Week == 5]

# %%
mapping_time2 = mapping_time2.drop("Week", axis=1)
mapping_time5 = mapping_time5.drop("Week", axis=1)

# %% [markdown]
# ## Time 5 16s

# %%
ax5 = bc_pcoa5.plot(mapping_time5, 'Category', axis_labels=('PC 1', 'PC 2', 'PC 3'), title='T2', cmap='Accent', s=50)
ax5.set_size_inches(12, 8)

# %%
results5_an = anosim(bc_dm5, mapping_time5, column='Category', permutations=999)
results5_an
# Out:
# method name                    ANOSIM
# test statistic name                 R
# sample size                        28
# number of groups                    4
# test statistic            0.000398216
# p-value                          0.47
# number of permutations            999
# Name: ANOSIM results, dtype: object

# %%
results5_p = permanova(bc_dm5, mapping_time5, column='Category', permutations=999)
results5_p
# Out:
# method name               PERMANOVA
# test statistic name        pseudo-F
# sample size                      28
# number of groups                  4
# test statistic             0.982079
# p-value                       0.486
# number of permutations          999
# Name: PERMANOVA results, dtype: object

# %% [markdown]
# ## Time 2 16s

# %%
df5 = pd.read_csv('t2_merged.tsv', sep='\t',index_col=0)
ids5 = list(df5.columns.values)
df5 = df5.T
data5 = df5.values.tolist()

# %%
df5
# Out:
# OTUID   1bbef1070bedf0db507fb6c7b5c28fff  54843b106b5061dc17ca8f371d357b44  \
# 570.T2                               878                                 0
# 571.T2                               191                               189
# 572.T2                               109                               156
# 573.T2                               249                               237
# 574.T2                               693                               617
# 575.T2                               317                               320
# 576.T2                               495                               384
# 577.T2                               129                               142
# 578.T2                               471                               494
# 580.T2                                44                                66
# 581.T2                                31                                45
# 582.T2                                62                                85
# 583.T2                               221                               251
# 584.T2                               225                               261
# 585.T2                                 0                                 0
# 586.T2                               414                               392
# 588.T2                               298                               296
# 589.T2                               197                               254
# 590.T2                               405                               361
# 592.T2                               511                               396
# 593.T2                               109                                85
# 594.T2                               121                                72
# 595.T2                              1271                               857
# 596.T2                               405                               349
# 597.T2                               291                               275
# 598.T2                               869                               609
# 599.T2                               136                               117
# 600.T2                              1275                              1068
# 601.T2                               954                              1139
# 602.T2                              1140                               996
# 603.T2                               753                               632
#
# OTUID   ff3c4e848cb548750221af3deb5389dc  646c18c31a1f6154773b7b8e64b5c658  \
# 570.T2                                 0                               835
# 571.T2                               123                               144
# 572.T2                               172                               137
# 573.T2                               141                               182
# 574.T2                               364                               426
# 575.T2                               216                               223
# 576.T2                               331                               380
# 577.T2                               133                               237
# 578.T2                               340                               336
# 580.T2                                38                                38
# 581.T2                                33                                39
# 582.T2                                97                                66
# 583.T2                               205                               215
# 584.T2                               202                               238
# 585.T2                               178                               185
# 586.T2                                 0                                 0
# 588.T2                               310                               326
# 589.T2                               196                               180
# 590.T2                               299                               254
# 592.T2                               209                               220
# 593.T2                                52                                57
# 594.T2                                54                               103
# 595.T2                                 0                               619
# 596.T2                               201                               215
# 597.T2                               218                               188
# 598.T2                               389                               412
# 599.T2                                67                                72
# 600.T2                               728                               642
# 601.T2                               820                               800
# 602.T2                               813                               778
# 603.T2                               665                               594
#
# OTUID   5171cbfbcd1781f0d7e7a7bdb94fb126  74803c74b50392f83753468b9235c931  \
# 570.T2                               807                                 0
# 571.T2                               164                               136
# 572.T2                               142                               167
# 573.T2                               189                               206
# 574.T2                               531                               465
# 575.T2                               211                               237
# 576.T2                               435                               366
# 577.T2                               110                               180
# 578.T2                               286                               299
# 580.T2                                 0                                54
# 581.T2                                 0                                37
# 582.T2                                69                                61
# 583.T2                               197                               191
# 584.T2                               218                               204
# 585.T2                                 0                                 0
# 586.T2                                 0                                 0
# 588.T2                               251                               276
# 589.T2                               178                               198
# 590.T2                               296                               320
# 592.T2                               232                               224
# 593.T2                                70                                57
# 594.T2                                80                                72
# 595.T2                               637                               523
# 596.T2                               252                               251
# 597.T2                               190                               184
# 598.T2                               515                               439
# 599.T2                                83                                84
# 600.T2                               882                               801
# 601.T2                               687                               746
# 602.T2                               815                               858
# 603.T2                               610                               636
#
# OTUID   2a2bbfefccc170850029ee0b903a7301  b90340baf132ddf80f4a342d544f1b03  \
# 570.T2                                 0                                 0
# 571.T2                                74                               112
# 572.T2                               174                               112
# 573.T2                               117                               131
# 574.T2                               188                               305
# 575.T2                               129                               172
# 576.T2                               242                               291
# 577.T2                                92                                99
# 578.T2                               236                               248
# 580.T2                                 0                                 0
# 581.T2                                35                                41
# 582.T2                                60                                64
# 583.T2                               267                               212
# 584.T2                               179                               183
# 585.T2                               189                                 0
# 586.T2                                 0                                 0
# 588.T2                               290                               269
# 589.T2                               145                               133
# 590.T2                               186                               236
# 592.T2                               160                               213
# 593.T2                                38                                61
# 594.T2                                36                                61
# 595.T2                                 0                               501
# 596.T2                               120                               188
# 597.T2                               154                               167
# 598.T2                               258                               351
# 599.T2                                52                                76
# 600.T2                               430                               641
# 601.T2                               662                               713
# 602.T2                               660                               751
# 603.T2                               563                               530
#
# OTUID   e305ca72b43b91c7a701c947a71ef4b7  ad4f3211c1c7fd39e69c4a22600a9475  \
# 570.T2                                 0                               520
# 571.T2                                79                               133
# 572.T2                               135                               108
# 573.T2                               117                               151
# 574.T2                               173                               341
# 575.T2                               131                               174
# 576.T2                               227                               347
# 577.T2                                98                               101
# 578.T2                               252                               274
# 580.T2                                26                                33
# 581.T2                                26                                31
# 582.T2                                65                                46
# 583.T2                               244                               173
# 584.T2                               170                               165
# 585.T2                                 0                                 0
# 586.T2                                 0                                 0
# 588.T2                               296                               239
# 589.T2                               147                               139
# 590.T2                               174                               233
# 592.T2                               164                               255
# 593.T2                                50                                67
# 594.T2                                54                                77
# 595.T2                                 0                               460
# 596.T2                               121                               208
# 597.T2                               154                               176
# 598.T2                               216                               437
# 599.T2                                63                                74
# 600.T2                               469                               712
# 601.T2                               655                               623
# 602.T2                               637                               817
# 603.T2                               546                               506
#
# OTUID   ...     156    157   158    159     160    161  162    163    164  \
# 570.T2  ...  109495      0     0      0       0      0    0      0      0
# 571.T2  ...   12121      0     0      0  215319  19458    0      0      0
# 572.T2  ...       0      0     0      0       0      0    0  52161      0
# 573.T2  ...   94254      0     0      0       0      0    0      0      0
# 574.T2  ...       0      0     0      0       0      0    0      0      0
# 575.T2  ...   24960      0     0      0       0      0    0      0      0
# 576.T2  ...   90501      0     0      0   16442      0    0      0      0
# 577.T2  ...  154443  13560     0      0       0      0    0      0      0
# 578.T2  ...       0      0     0  23337       0      0    0      0      0
# 580.T2  ...   59602      0     0      0  156676      0    0      0      0
# 581.T2  ...       0      0     0      0       0      0    0      0      0
# 582.T2  ...       0      0     0      0       0      0    0      0      0
# 583.T2  ...       0      0     0      0       0      0    0      0      0
# 584.T2  ...       0      0     0      0       0      0    0      0      0
# 585.T2  ...       0      0     0      0       0      0    0      0      0
# 586.T2  ...       0      0     0      0       0      0    0      0      0
# 588.T2  ...       0      0     0      0       0      0    0      0      0
# 589.T2  ...   52467      0     0  16117       0   9263    0      0      0
# 590.T2  ...  147340      0     0      0       0      0    0      0      0
# 592.T2  ...   94423      0     0      0       0      0    0  30902      0
# 593.T2  ...       0      0     0      0       0      0    0  60317      0
# 594.T2  ...  412492      0     0      0       0      0    0      0      0
# 595.T2  ...  392448      0     0      0       0      0    0      0      0
# 596.T2  ...       0      0     0      0       0      0    0      0      0
# 597.T2  ...  315038      0     0      0       0      0    0      0      0
# 598.T2  ...   36146      0     0      0       0      0    0      0      0
# 599.T2  ...   89768      0  7321      0       0  28463    0      0      0
# 600.T2  ...  616327      0     0      0       0      0    0      0      0
# 601.T2  ...  329361      0     0      0       0      0    0   9771      0
# 602.T2  ...  230932      0     0      0       0      0    0      0      0
# 603.T2  ...   84687      0     0  23331       0   3540    0      0  20734
#
# OTUID     165
# 570.T2      0
# 571.T2      0
# 572.T2      0
# 573.T2   8058
# 574.T2      0
# 575.T2      0
# 576.T2      0
# 577.T2      0
# 578.T2      0
# 580.T2   3045
# 581.T2      0
# 582.T2      0
# 583.T2      0
# 584.T2      0
# 585.T2      0
# 586.T2      0
# 588.T2      0
# 589.T2   9604
# 590.T2  15988
# 592.T2  11892
# 593.T2      0
# 594.T2      0
# 595.T2   6658
# 596.T2      0
# 597.T2   2462
# 598.T2      0
# 599.T2   2210
# 600.T2  15125
# 601.T2  12254
# 602.T2      0
# 603.T2   2198
#
# [31 rows x 357 columns]

# %%
bc_dm5 = beta_diversity("braycurtis", data5, ids5)

# %%
bc_dm5

# %%
bc_pcoa5 = pcoa(bc_dm5)
# Out:
# /home/basilin/anaconda3/envs/qiime2020/lib/python3.6/site-packages/skbio/stats/ordination/_principal_coordinate_analysis.py:152: RuntimeWarning: The result contains negative eigenvalues. Please compare their magnitude with the magnitude of some of the largest positive eigenvalues. If the negative ones are smaller, it's probably safe to ignore them, but if they are large in magnitude, the results won't be useful. See the Notes section for more details. The smallest eigenvalue is -0.05117260110986506 and the largest is 1.4466088128835963.
#   RuntimeWarning

# %%
ax5 = bc_pcoa5.plot(mapping_time2, 'Category', axis_labels=('PC 1', 'PC 2', 'PC 3'), title='T2', cmap='Accent', s=50)
ax5.set_size_inches(12, 8)

# %%
results5_an = anosim(bc_dm5, mapping_time2, column='Category', permutations=999)
results5_an
# Out:
# method name                 ANOSIM
# test statistic name              R
# sample size                     31
# number of groups                 4
# test statistic            0.336455
# p-value                      0.001
# number of permutations         999
# Name: ANOSIM results, dtype: object

# %%
results5_p = permanova(bc_dm5, mapping_time2, column='Category', permutations=999)
results5_p
# Out:
# method name               PERMANOVA
# test statistic name        pseudo-F
# sample size                      31
# number of groups                  4
# test statistic              2.86923
# p-value                       0.001
# number of permutations          999
# Name: PERMANOVA results, dtype: object
