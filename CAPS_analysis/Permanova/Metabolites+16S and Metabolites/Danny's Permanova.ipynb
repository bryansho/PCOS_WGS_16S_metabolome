# %%
import pandas as pd
from skbio.diversity import beta_diversity
from skbio.stats.ordination import pcoa
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
from skbio.stats.distance import anosim
from skbio.stats.distance import permanova

# %% [markdown]
# # T2

# %%
df = pd.read_csv('Unknown_Cutoff_T2_No-OTU.csv')
ids = list(df.columns.values)
df = df.T
data = df.values.tolist()
bc_dm = beta_diversity("braycurtis", data, ids)
bc_pcoa = pcoa(bc_dm)

# %%
mapping = pd.read_csv('Map_file.csv', index_col=0)
ax = bc_pcoa.plot(mapping, 'Category', axis_labels=('PC 1', 'PC 2', 'PC 3'), title='T2', cmap='Accent', s=50)
ax.set_size_inches(12, 8)

# %%
results = anosim(bc_dm, mapping, column='Category', permutations=999)
results
# Out:
# method name                 ANOSIM
# test statistic name              R
# sample size                     32
# number of groups                 4
# test statistic            0.640439
# p-value                      0.001
# number of permutations         999
# Name: ANOSIM results, dtype: object

# %%
results = permanova(bc_dm, mapping, column='Category', permutations=999)
results
# Out:
# method name               PERMANOVA
# test statistic name        pseudo-F
# sample size                      32
# number of groups                  4
# test statistic              6.92505
# p-value                       0.001
# number of permutations          999
# Name: PERMANOVA results, dtype: object

# %% [markdown]
# # T5

# %%
df = pd.read_csv('Unknown_Cutoff_T5_No-OTU.csv')
ids = list(df.columns.values)
df = df.T
data = df.values.tolist()
bc_dm = beta_diversity("braycurtis", data, ids)
bc_pcoa = pcoa(bc_dm)

# %%
mapping = pd.read_csv('Map_file.csv', index_col=0)
ax = bc_pcoa.plot(mapping, 'Category', axis_labels=('PC 1', 'PC 2', 'PC 3'), title='T2', cmap='Accent', s=50)
ax.set_size_inches(12, 8)

# %%
results = anosim(bc_dm, mapping, column='Category', permutations=999)
results
# Out:
# method name                  ANOSIM
# test statistic name               R
# sample size                      32
# number of groups                  4
# test statistic            0.0929594
# p-value                       0.023
# number of permutations          999
# Name: ANOSIM results, dtype: object

# %%
results = permanova(bc_dm, mapping, column='Category', permutations=999)
results
# Out:
# method name               PERMANOVA
# test statistic name        pseudo-F
# sample size                      32
# number of groups                  4
# test statistic              1.47057
# p-value                       0.012
# number of permutations          999
# Name: PERMANOVA results, dtype: object

# %% [markdown]
# # T0

# %%
df = pd.read_csv('Unknown_Cutoff_T0_No-OTU.csv')
ids = list(df.columns.values)
df = df.T
data = df.values.tolist()
bc_dm = beta_diversity("braycurtis", data, ids)
bc_pcoa = pcoa(bc_dm)
mapping = pd.read_csv('Map_file.csv', index_col=0)
ax = bc_pcoa.plot(mapping, 'Category', axis_labels=('PC 1', 'PC 2', 'PC 3'), title='T2', cmap='Accent', s=50)
ax.set_size_inches(12, 8)

# %%
results = anosim(bc_dm, mapping, column='Category', permutations=999)
results
# Out:
# method name                   ANOSIM
# test statistic name                R
# sample size                       32
# number of groups                   4
# test statistic           -0.00483631
# p-value                        0.494
# number of permutations           999
# Name: ANOSIM results, dtype: object

# %%
results = permanova(bc_dm, mapping, column='Category', permutations=999)
results
# Out:
# method name               PERMANOVA
# test statistic name        pseudo-F
# sample size                      32
# number of groups                  4
# test statistic             0.942322
# p-value                       0.587
# number of permutations          999
# Name: PERMANOVA results, dtype: object

# %% [markdown]
# # T1

# %%
df = pd.read_csv('Unknown_Cutoff_T1_No-OTU.csv')
ids = list(df.columns.values)
df = df.T
data = df.values.tolist()
bc_dm = beta_diversity("braycurtis", data, ids)
bc_pcoa = pcoa(bc_dm)
mapping = pd.read_csv('Map_file.csv', index_col=0)
ax = bc_pcoa.plot(mapping, 'Category', axis_labels=('PC 1', 'PC 2', 'PC 3'), title='T2', cmap='Accent', s=50)
ax.set_size_inches(12, 8)

# %%
results = anosim(bc_dm, mapping, column='Category', permutations=999)
results
# Out:
# method name                 ANOSIM
# test statistic name              R
# sample size                     32
# number of groups                 4
# test statistic            0.217169
# p-value                      0.001
# number of permutations         999
# Name: ANOSIM results, dtype: object

# %%
results = permanova(bc_dm, mapping, column='Category', permutations=999)
results
# Out:
# method name               PERMANOVA
# test statistic name        pseudo-F
# sample size                      32
# number of groups                  4
# test statistic              1.78761
# p-value                       0.002
# number of permutations          999
# Name: PERMANOVA results, dtype: object

# %% [markdown]
# # T3

# %%
df = pd.read_csv('Unknown_Cutoff_T3_No-OTU.csv')
ids = list(df.columns.values)
df = df.T
data = df.values.tolist()
bc_dm = beta_diversity("braycurtis", data, ids)
bc_pcoa = pcoa(bc_dm)
mapping = pd.read_csv('Map_file.csv', index_col=0)
ax = bc_pcoa.plot(mapping, 'Category', axis_labels=('PC 1', 'PC 2', 'PC 3'), title='T2', cmap='Accent', s=50)
ax.set_size_inches(12, 8)

# %%
results = anosim(bc_dm, mapping, column='Category', permutations=999)
results
# Out:
# method name                ANOSIM
# test statistic name             R
# sample size                    32
# number of groups                4
# test statistic            0.13351
# p-value                      0.01
# number of permutations        999
# Name: ANOSIM results, dtype: object

# %%
results = permanova(bc_dm, mapping, column='Category', permutations=999)
results
# Out:
# method name               PERMANOVA
# test statistic name        pseudo-F
# sample size                      32
# number of groups                  4
# test statistic              1.46919
# p-value                       0.014
# number of permutations          999
# Name: PERMANOVA results, dtype: object

# %% [markdown]
# # T4

# %%
df = pd.read_csv('Unknown_Cutoff_T4_No-OTU.csv')
ids = list(df.columns.values)
df = df.T
data = df.values.tolist()
bc_dm = beta_diversity("braycurtis", data, ids)
bc_pcoa = pcoa(bc_dm)
mapping = pd.read_csv('Map_file.csv', index_col=0)
ax = bc_pcoa.plot(mapping, 'Category', axis_labels=('PC 1', 'PC 2', 'PC 3'), title='T2', cmap='Accent', s=50)
ax.set_size_inches(12, 8)

# %%
results = anosim(bc_dm, mapping, column='Category', permutations=999)
results
# Out:
# method name                  ANOSIM
# test statistic name               R
# sample size                      32
# number of groups                  4
# test statistic            0.0391555
# p-value                       0.195
# number of permutations          999
# Name: ANOSIM results, dtype: object

# %%
results = permanova(bc_dm, mapping, column='Category', permutations=999)
results
# Out:
# method name               PERMANOVA
# test statistic name        pseudo-F
# sample size                      32
# number of groups                  4
# test statistic              1.16763
# p-value                       0.175
# number of permutations          999
# Name: PERMANOVA results, dtype: object

# %% [markdown]
# # Metabolite + 16S T2

# %%
df = pd.read_csv('Metabolites_16S_T2_no_OTU.csv')
ids = list(df.columns.values)
df = df.T
data = df.values.tolist()
bc_dm = beta_diversity("braycurtis", data, ids)
bc_pcoa = pcoa(bc_dm)
mapping = pd.read_csv('Map_file.csv', index_col=0)
ax = bc_pcoa.plot(mapping, 'Category', axis_labels=('PC 1', 'PC 2', 'PC 3'), title='T2', cmap='Accent', s=50)
ax.set_size_inches(12, 8)

# %%
results = anosim(bc_dm, mapping, column='Category', permutations=999)
results
# Out:
# method name                 ANOSIM
# test statistic name              R
# sample size                     32
# number of groups                 4
# test statistic            0.640439
# p-value                      0.001
# number of permutations         999
# Name: ANOSIM results, dtype: object

# %%
results = permanova(bc_dm, mapping, column='Category', permutations=999)
results
# Out:
# method name               PERMANOVA
# test statistic name        pseudo-F
# sample size                      32
# number of groups                  4
# test statistic              6.92504
# p-value                       0.001
# number of permutations          999
# Name: PERMANOVA results, dtype: object

# %% [markdown]
# # Metabolite + 16S T5

# %%
df = pd.read_csv('Metabolites_16S_T5_no_OTU.csv')
ids = list(df.columns.values)
df = df.T
data = df.values.tolist()
bc_dm = beta_diversity("braycurtis", data, ids)
bc_pcoa = pcoa(bc_dm)
mapping = pd.read_csv('Map_file.csv', index_col=0)
ax = bc_pcoa.plot(mapping, 'Category', axis_labels=('PC 1', 'PC 2', 'PC 3'), title='T2', cmap='Accent', s=50)
ax.set_size_inches(12, 8)

# %%
results = anosim(bc_dm, mapping, column='Category', permutations=999)
results
# Out:
# method name                  ANOSIM
# test statistic name               R
# sample size                      28
# number of groups                  4
# test statistic            0.0899172
# p-value                       0.064
# number of permutations          999
# Name: ANOSIM results, dtype: object

# %%
results = permanova(bc_dm, mapping, column='Category', permutations=999)
results
# Out:
# method name               PERMANOVA
# test statistic name        pseudo-F
# sample size                      28
# number of groups                  4
# test statistic              1.32499
# p-value                        0.06
# number of permutations          999
# Name: PERMANOVA results, dtype: object
